# %% [markdown]
# ## Cornell movie dataset preprocessing

# %%
import json
import ast
with open("cornell-movie-dialogs-corpus/movie_conversations.txt", buffering=1000, encoding='utf8', errors='ignore') as f:
    for row in f:
        line = row.split(" +++$+++ ")
        x = ast.literal_eval(line[3].replace("\n",""))
        lines.append(x)
lines[:10]
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366']]

# %%
import re
def preprocess_sentence(w):
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r'\.\.+',".",w)
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

    w = w.rstrip().strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
data = {}
with open("cornell-movie-dialogs-corpus/movie_lines.txt", "r", encoding='utf-8', errors='ignore') as f:
    for row in f:
        try:
            
            line = row.split(" +++$+++ ")
            data[line[0]] = preprocess_sentence(line[4].replace("\n",""))
        except Exception as e:
            print(row)
data
# Out:
# {'L1045': '<start> They do not ! <end>',
#  'L1044': '<start> They do to ! <end>',
#  'L985': '<start> I hope so . <end>',
#  'L984': '<start> She okay ? <end>',
#  'L925': '<start> Let s go . <end>',
#  'L924': '<start> Wow <end>',
#  'L872': '<start> Okay you re gonna need to learn how to lie . <end>',
#  'L871': '<start> No <end>',
#  'L870': '<start> I m kidding . You know how sometimes you just become this persona ? And you don t know how to quit ? <end>',
#  'L869': '<start> Like my fear of wearing pastels ? <end>',
#  'L868': '<start> The real you . <end>',
#  'L867': '<start> What good stuff ? <end>',
#  'L866': '<start> I figured you d get to the good stuff eventually . <end>',
#  'L865': '<start> Thank God ! If I had to hear one more story about your coiffure . <end>',
#  'L864': '<start> Me . This endless . blonde babble . I m like , boring myself . <end>',
#  'L863': '<start> What crap ? <end>',
#  'L862': '<start> do you listen to this crap ? <end>',
#  'L861': '<start> No . <end>',
#  'L860': '<start> Then Guillermo says , If you go any lighter , you re gonna look like an extra on . <end>',
#  'L699': '<start> You always been this selfish ? <end>',
#  'L698': '<start> But <end>',
#  'L697': '<start> Then that s all you had to say . <end>',
#  'L696': '<start> Well , no . <end>',
#  'L695': '<start> You never wanted to go out with me , did you ? <end>',
#  'L694': '<start> I was ? <end>',
#  'L693': '<start> I looked for you back at the party , but you always seemed to be occupied . <end>',
#  'L663': '<start> Tons <end>',
#  'L662': '<start> Have fun tonight ? <end>',
#  'L578': '<start> I believe we share an art instructor <end>',
#  'L577': '<start> You know Chastity ? <end>',
#  'L576': '<start> Looks like things worked out tonight , huh ? <end>',
#  'L575': '<start> Hi . <end>',
#  'L407': '<start> Who knows ? All I ve ever heard her say is that she d dip before dating a guy that smokes . <end>',
#  'L406': '<start> So that s the kind of guy she likes ? Pretty ones ? <end>',
#  'L405': '<start> Lesbian ? No . I found a picture of Jared Leto in one of her drawers , so I m pretty sure she s not harboring same sex tendencies . <end>',
#  'L404': '<start> She s not a . <end>',
#  'L403': '<start> I m workin on it . But she doesn t seem to be goin for him . <end>',
#  'L402': '<start> I really , really , really wanna go , but I can t . Not unless my sister goes . <end>',
#  'L401': '<start> Sure have . <end>',
#  'L368': '<start> Eber s Deep Conditioner every two days . And I never , ever use a blowdryer without the diffuser attachment . <end>',
#  'L367': '<start> How do you get your hair to look like that ? <end>',
#  'L366': '<start> You re sweet . <end>',
#  'L365': '<start> You have my word . As a gentleman <end>',
#  'L364': '<start> I counted on you to help my cause . You and that thug are obviously failing . Aren t we ever going on our date ? <end>',
#  'L363': '<start> You got something on your mind ? <end>',
#  'L281': '<start> Where ? <end>',
#  'L280': '<start> There . <end>',
#  'L277': '<start> Well , there s someone I think might be <end>',
#  'L276': '<start> How is our little Find the Wench A Date plan progressing ? <end>',
#  'L275': '<start> Forget French . <end>',
#  'L274': '<start> That s because it s such a nice one . <end>',
#  'L273': '<start> I don t want to know how to say that though . I want to know useful things . Like where the good stores are . How much does champagne cost ? Stuff like Chat . I have never in my life had to point out my head to someone . <end>',
#  'L272': '<start> Right . See ? You re ready for the quiz . <end>',
#  'L271': '<start> C esc ma tete . This is my head <end>',
#  'L208': '<start> Let me see what I can do . <end>',
#  'L207': '<start> Gosh , if only we could find Kat a boyfriend . <end>',
#  'L206': '<start> That s a shame . <end>',
#  'L205': '<start> Unsolved mystery . She used to be really popular when she started high school , then it was just like she got sick of it or something . <end>',
#  'L204': '<start> Why ? <end>',
#  'L203': '<start> Seems like she could get a date easy enough . <end>',
#  'L202': '<start> The thing is , Cameron I m at the mercy of a particularly hideous breed of loser . My sister . I can t date until she does . <end>',
#  'L201': '<start> Cameron . <end>',
#  'L200': '<start> No , no , it s my fault we didn t have a proper introduction <end>',
#  'L199': '<start> Forget it . <end>',
#  'L198': '<start> You re asking me out . That s so cute . What s your name again ? <end>',
#  'L197': '<start> Okay . then how bout we try out some French cuisine . Saturday ? Night ? <end>',
#  'L196': '<start> Not the hacking and gagging and spitting part . Please . <end>',
#  'L195': '<start> Well , I thought we d start with pronunciation , if that s okay with you . <end>',
#  'L194': '<start> Can we make this quick ? Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break up on the quad . Again . <end>',
#  'L953': '<start> I did . <end>',
#  'L952': '<start> You think you re the only sophomore at the prom ? <end>',
#  'L660': '<start> I don t have to be home til two . <end>',
#  'L659': '<start> I have to be home in twenty minutes . <end>',
#  'L600': '<start> All I know is I d give up my private line to go out with a guy like Joey . <end>',
#  'L599': '<start> Sometimes I wonder if the guys we re supposed to want to go out with are the ones we actually want to go out with , you know ? <end>',
#  'L598': '<start> Bianca , I don t think the highlights of dating Joey Dorsey are going to include door opening and coat holding . <end>',
#  'L597': '<start> Combination . I don t know I thought he d be different . More of a gentleman . <end>',
#  'L596': '<start> Is he oily or dry ? <end>',
#  'L595': '<start> He practically proposed when he found out we had the same dermatologist . I mean . Dr . Bonchowski is great an all , but he s not exactly relevant party conversation . <end>',
#  'L580': '<start> Would you mind getting me a drink , Cameron ? <end>',
#  'L579': '<start> Great <end>',
#  'L573': '<start> Joey . <end>',
#  'L572': '<start> Who ? <end>',
#  'L571': '<start> Where did he go ? He was just here . <end>',
#  'L51': '<start> You might wanna think about it <end>',
#  'L50': '<start> No . <end>',
#  'L49': '<start> Did you change your hair ? <end>',
#  'L760': '<start> You know the deal . I can t go if Kat doesn t go <end>',
#  'L759': '<start> Listen , I want to talk to you about the prom . <end>',
#  'L758': '<start> You re concentrating awfully hard considering it s gym class . <end>',
#  'L757': '<start> Hi , Joey . <end>',
#  'L756': '<start> Hey , sweet cheeks . <end>',
#  'L593': '<start> My agent says I ve got a good shot at being the Prada guy next year . <end>',
#  'L592': '<start> Neat . <end>',
#  'L591': '<start> It s a gay cruise line , but I ll be , like , wearing a uniform and stuff . <end>',
#  'L590': '<start> Queen Harry ? <end>',
#  'L589': '<start> So yeah , I ve got the Sears catalog thing going and the tube sock gig that s gonna be huge . And then I m up for an ad for Queen Harry next week . <end>',
#  'L397': '<start> Hopefully . <end>',
#  'L396': '<start> Exactly So , you going to Bogey Lowenbrau s thing on Saturday ? <end>',
#  'L395': '<start> Expensive ? <end>',
#  'L394': '<start> It s more <end>',
#  'L1052': '<start> Perm ? <end>',
#  'L1051': '<start> Patrick is that a . <end>',
#  'L1022': '<start> It s just you . <end>',
#  'L1021': '<start> Is that woman a complete fruit loop or is it just me ? <end>',
#  'L1011': '<start> No ! I just wanted <end>',
#  'L1010': '<start> What ? To completely damage me ? To send me to therapy forever ? What ? <end>',
#  'L1009': '<start> I just wanted <end>',
#  'L1008': '<start> You set me up . <end>',
#  'L1007': '<start> Let go ! <end>',
#  'L983': '<start> So did you <end>',
#  'L982': '<start> You looked beautiful last night , you know . <end>',
#  'L914': '<start> I guess I ll never know , will I ? <end>',
#  'L913': '<start> Not all experiences are good , Bianca . You can t always trust the people you want to . <end>',
#  'L912': '<start> God , you re just like him ! Just keep me locked away in the dark , so I can t experience anything for myself <end>',
#  'L911': '<start> I guess I thought I was protecting you . <end>',
#  'L910': '<start> I m not stupid enough to repeat your mistakes . <end>',
#  'L909': '<start> That s not <end>',
#  'L908': '<start> No . you didn t ! If you really thought I could make my own decisions , you would ve let me go out with him instead of helping Daddy hold me hostage . <end>',
#  'L907': '<start> I wanted to let you make up your own mind about him . <end>',
#  'L906': '<start> Why didn t you tell me ? <end>',
#  'L905': '<start> After that , I swore I d never do anything just because everyone else was doing it . And I haven t since . Except for Bogey s party , and my stunning gastro intestinal display <end>',
#  'L904': '<start> But <end>',
#  'L903': '<start> Just once . Afterwards , I told him I didn t want to anymore . I wasn t ready . He got pissed . Then he broke up with me . <end>',
#  'L902': '<start> You did what ? <end>',
#  'L901': '<start> He said everyone was doing it . So I did it . <end>',
#  'L900': '<start> As in . <end>',
#  'L899': '<start> Now I do . Back then , was a different story . <end>',
#  'L898': '<start> But you hate Joey <end>',
#  'L897': '<start> He was , like , a total babe <end>',
#  'L896': '<start> Why ? <end>',
#  'L895': '<start> In th . For a month <end>',
#  'L894': '<start> What ? <end>',
#  'L893': '<start> Joey never told you we went out , did he ? <end>',
#  'L892': '<start> I wish I had that luxury . I m the only sophomore that got asked to the prom and I can t go , because you won t . <end>',
#  'L891': '<start> I do care . But I m a firm believer in doing something for your own reasons , not someone else s . <end>',
#  'L890': '<start> Like you care . <end>',
#  'L889': '<start> Listen , I know you hate having to sit home because I m not Susie High School . <end>',
#  'L656': '<start> You re welcome . <end>',
#  'L655': '<start> I don t get you . You act like you re too good for any of this , and then you go totally apeshit when you get here . <end>',
#  'L602': '<start> I really don t think I need any social advice from you right now . <end>',
#  'L601': '<start> Bianca , I need to talk to you I need to tell you <end>',
#  'L543': '<start> Can we go now ? <end>',
#  'L542': '<start> You are so completely unbalanced . <end>',
#  'L533': '<start> Yeah , he s your freak friend Mandella s boyfriend . I guess since I m not allowed to go out , I should obsess over a dead guy , too . <end>',
#  'L532': '<start> It s Shakespeare . Maybe you ve heard of him ? <end>',
#  'L531': '<start> Like I m supposed to know what that even means . <end>',
#  'L530': '<start> At least I m not a clouted fen sucked hedge pig . <end>',
#  'L529': '<start> Can t you forget for just one night that you re completely wretched ? <end>',
#  'L527': '<start> Bogey Lowenstein s party is normal , but you re too busy listening to Bitches Who Need Prozac to know that . <end>',
#  'L526': '<start> What s normal ? <end>',
#  'L525': '<start> You re ruining my life Because you won t be normal , I can t be normal . <end>',
#  'L445': '<start> I think you re a freak . I think you do this to torture me . And I think you suck . <end>',
#  'L444': '<start> What do you think ? <end>',
#  'L443': '<start> Oh , I thought you might have a date I don t know why I m bothering to ask , but are you going to Bogey Lowenstein s party Saturday night ? <end>',
#  'L442': '<start> It means that Gigglepuss is playing at Club Skunk and we re going . <end>',
#  'L441': '<start> Oh my God , does this mean you re becoming normal ? <end>',
#  'L320': '<start> Can you at least start wearing a bra ? <end>',
#  'L319': '<start> I have the potential to smack the crap out of you if you don t get out of my way . <end>',
#  'L165': '<start> Nowhere . Hi , Daddy . <end>',
#  'L164': '<start> Where ve you been ? <end>',
#  'L923': '<start> I have a date , Daddy . And he s not a captain of oppression like some men we know . <end>',
#  'L922': '<start> I m missing something . <end>',
#  'L884': '<start> Fine . I see that I m a prisoner in my own house . I m not a daughter . I m a possession ! <end>',
#  'L883': '<start> You re not going unless your sister goes . End of story . <end>',
#  'L882': '<start> He s not a hot rod . Whatever that is . <end>',
#  'L881': '<start> It s that hot rod Joey , right ? That s who you want me to bend my rules for ? <end>',
#  'L880': '<start> No , but <end>',
#  'L879': '<start> The prom ? Kat has a date ? <end>',
#  'L878': '<start> Daddy , I want to discuss the prom with you . It s tomorrow night <end>',
#  'L546': '<start> Because she ll scare them away . <end>',
#  'L545': '<start> Why ? <end>',
#  'L544': '<start> Promise me you won t talk to any boys unless your sister is present . <end>',
#  'L540': '<start> Just for a minute <end>',
#  'L539': '<start> Daddy , no ! <end>',
#  'L538': '<start> Wear the belly before you go . <end>',
#  'L537': '<start> It s just a party . Daddy . <end>',
#  'L536': '<start> Oh , God . It s starting . <end>',
#  'L524': '<start> If Kat s not going , you re not going . <end>',
#  'L523': '<start> Daddy , people expect me to be there ! <end>',
#  'L521': '<start> It s just a party . Daddy , but I knew you d forbid me to go since Gloria Steinem over there isn t going <end>',
#  'L520': '<start> Otherwise known as an orgy ? <end>',
#  'L519': '<start> If you must know , we were attempting to go to a small study group of friends . <end>',
#  'L518': '<start> And where re you going ? <end>',
#  'L517': '<start> Daddy , I <end>',
#  'L190': '<start> Exactly my point <end>',
#  'L189': '<start> But she doesn t want to date . <end>',
#  'L183': '<start> But it s not fair she s a mutant , Daddy ! <end>',
#  'L182': '<start> Then neither will you . And I ll get to sleep at night . <end>',
#  'L181': '<start> What if she never starts dating ? <end>',
#  'L180': '<start> No ! You re not dating until your sister starts dating . End of discussion . <end>',
#  'L179': '<start> Now don t get upset . Daddy , but there s this boy . and I think he might ask . <end>',
#  'L463': '<start> Just sent em through . <end>',
#  'L462': '<start> Padua girls . One tall , decent body . The other one kinda short and undersexed ? <end>',
#  'L461': '<start> Never <end>',
#  'L460': '<start> Fan of a fan . You see a couple of minors come in ? <end>',
#  'L459': '<start> Didn t have you pegged for a Gigglepuss fan . Aren t they a little too pre teen belly button ring for you ? <end>',
#  'L458': '<start> Always a pleasure , Brucie . <end>',
#  'L779': '<start> Best case scenario , you re back on the payroll for awhile . <end>',
#  'L778': '<start> You humiliated the woman ! Sacrifice yourself on the altar of dignity and even the score . <end>',
#  'L586': '<start> No , I m not . <end>',
#  'L585': '<start> Buttholus extremus . But hey , you re making progress . <end>',
#  'L584': '<start> The hell is that ? What kind of guy just picks up a girl and carries her away while you re talking to her ? <end>',
#  'L583': '<start> Extremely unfortunate maneuver . <end>',
#  'L500': '<start> Hell , I ve just been going over the whole thing in my head and <end>',
#  'L499': '<start> You told me that part already . <end>',
#  'L433': '<start> It s her favorite band . <end>',
#  'L432': '<start> Assail your ears for one night . <end>',
#  'L425': '<start> Okay ! I wasn t sure <end>',
#  'L424': '<start> He s pretty ! <end>',
#  'L419': '<start> Dead at forty one . <end>',
#  'L418': '<start> Her favorite uncle <end>',
#  'L417': '<start> It s a lung cancer issue <end>',
#  'L416': '<start> Number one . She hates smokers <end>',
#  'L391': '<start> Are you kidding ? He ll piss himself with joy . He s the ultimate kiss ass . <end>',
#  'L390': '<start> Will Bogey get bent ? <end>',
#  'L389': '<start> In that case , we ll need to make it a school wide blow out . <end>',
#  'L388': '<start> This is it . A golden opportunity . Patrick can ask Katarina to the party . <end>',
#  'L245': '<start> Like we had a choice ? Besides when you let the enemy think he s orchestrating the battle , you re in a position of power . We let him pretend he s calling the shots , and while he s busy setting up the plan , you have time to woo Bianca . <end>',
#  'L244': '<start> You got him involved ? <end>',
#  'L225': '<start> Hey I ve gotta have a few clients when I get to Wall Street . <end>',
#  'L224': '<start> I thought you hated those people . <end>',
#  'L223': '<start> You know , if you do go out with Bianca , you d be set . You d outrank everyone . Strictly A list . With me by your side . <end>',
#  'L222': '<start> That s what I just said <end>',
#  'L221': '<start> Did she actually say she d go out with you ? <end>',
#  'L220': '<start> Forget his reputation . Do you think we ve got a plan or not ? <end>',
#  'L219': '<start> I m serious , man , he s whacked . He sold his own liver on the black market so he could buy new speakers . <end>',
#  'L218': '<start> They always let felons sit in on Honors Biology ? <end>',
#  'L217': '<start> No kidding . He s a criminal . I heard he lit a state trooper on fire . He just got out of Alcatraz . <end>',
#  'L216': '<start> He seems like he thrives on danger <end>',
#  'L215': '<start> What makes you think he ll do it ? <end>',
#  'L213': '<start> You wanna go out with him ? <end>',
#  'L212': '<start> What about him ? <end>',
#  'L211': '<start> Unlikely , but even so , she still can t go out with you . So what s the point ? <end>',
#  'L210': '<start> I teach her French , get to know her , dazzle her with charm and she falls in love with me . <end>',
#  'L159': '<start> The mewling , rampalian wretch herself . <end>',
#  'L158': '<start> That s her ? Bianca s sister ? <end>',
#  'L157': '<start> Yeah , just a minor encounter with the shrew . <end>',
#  'L147': '<start> You could consecrate with her , my friend . <end>',
#  'L146': '<start> You mean I d get a chance to talk to her ? <end>',
#  'L145': '<start> Guess who just signed up for a tutor ? <end>',
#  'L144': '<start> Sure do . my Mom s from Canada <end>',
#  'L143': '<start> You know French ? <end>',
#  'L142': '<start> Joey Dorsey ? Perma shit grin . I wish I could say he s a moron , but he s number twelve in the class . And a model . Mostly regional stuff , but he s rumored to have a big tube sock ad coming out . <end>',
#  'L141': '<start> He always have that shit eating grin ? <end>',
#  'L140': '<start> Because they re bred to . Their mothers liked guys like that , and their grandmothers before them . Their gene pool is rarely diluted . <end>',
#  'L139': '<start> Why do girls like that always like guys like that ? <end>',
#  'L92': '<start> I could start with your haircut , but it doesn t matter . She s not allowed to date until her older sister does . And that s an impossibility . <end>',
#  'L91': '<start> Why not ? <end>',
#  'L90': '<start> Bianca Stratford . Sophomore . Don t even think about it <end>',
#  'L89': '<start> Who is she ? <end>',
#  'L88': '<start> You burn , you pine , you perish ? <end>',
#  'L87': '<start> That girl I <end>',
#  'L78': '<start> Yeah , but these guys have never seen a horse . They just jack off to Clint Eastwood . <end>',
#  'L77': '<start> That I m used to . <end>',
#  'L74': '<start> Couple thousand . Most of them evil <end>',
#  'L73': '<start> How many people go here ? <end>',
#  'L72': '<start> Get out ! <end>',
#  'L71': '<start> Thirty two . <end>',
#  'L70': '<start> How many people were in your old school ? <end>',
#  'L69': '<start> Yeah . A couple . We re outnumbered by the cows , though . <end>',
#  'L68': '<start> I was kidding . People actually live there ? <end>',
#  'L67': '<start> North , actually . How d you ? <end>',
#  'L66': '<start> So which Dakota you from ? <end>',
#  'L65': '<start> C mon . I m supposed to give you the tour . <end>',
#  'L64': '<start> So they tell me . <end>',
#  'L63': '<start> You the new guy ? <end>',
#  'L781': '<start> You get the girl . <end>',
#  'L780': '<start> What s the worst ? <end>',
#  'L745': '<start> Where ? <end>',
#  'L744': '<start> She kissed me . <end>',
#  'L743': '<start> You makin any headway ? <end>',
#  'L741': '<start> She just needs time to cool off I ll give it a day . <end>',
#  'L740': '<start> She hates you with the fire of a thousand suns . That s a direct quote <end>',
#  'L726': '<start> I don t know . I decided not to nail her when she was too drunk to remember it . <end>',
#  'L725': '<start> What d you do to her ? <end>',
#  'L625': '<start> Then , go get her <end>',
#  'L624': '<start> Sure <end>',
#  'L623': '<start> Cameron do you like the girl ? <end>',
#  'L622': '<start> She s partial to Joey , not me <end>',
#  'L621': '<start> What re you talking about ? <end>',
#  'L620': '<start> It s off . The whole thing . <end>',
#  'L619': '<start> Cameron , I m a little busy <end>',
#  'L431': '<start> Don t make me do it , man <end>',
#  'L430': '<start> Gigglepuss is playing there tomorrow night . <end>',
#  'L427': '<start> So what does that give me ? I m supposed to buy her some noodles and a book and sit around listening to chicks who can t play their instruments ? <end>',
#  'L426': '<start> Okay Likes Thai food , feminist prose , and angry , stinky girl music of the indie rock persuasion . <end>',
#  'L412': '<start> I ve retrieved certain pieces of information on Miss Katarina Stratford I think you ll find helpful . <end>',
#  'L411': '<start> What ve you got for me ? <end>',
#  'L386': '<start> Yeah we ll see . <end>',
#  'L385': '<start> And he means that strictly in a non prison movie type of way . <end>',
#  'L558': '<start> And why would I do that ? <end>',
#  'L557': '<start> Leave my sister alone . <end>',
#  'L556': '<start> Your sister here ? <end>',
#  'L555': '<start> Away . <end>',
#  'L554': '<start> Where ya goin ? <end>',
#  'L336': '<start> Not at all <end>',
#  'L335': '<start> Hey do you mind ? <end>',
#  'L150': '<start> They re running the rest of me next month . <end>',
#  'L149': '<start> Yeah , and I noticed the only part of you featured in your big Kmart spread was your elbow . Tough break . <end>',
#  'L148': '<start> The vintage look is over , Kat . Haven t you been reading your Sassy ? <end>',
#  'L748': '<start> Enough with the Barbie n Ken shit . I know . <end>',
#  'L747': '<start> I don t know , Dorsey . . the limo . the flowers . Another hundred for the tux <end>',
#  'L609': '<start> Get her to act like a human <end>',
#  'L608': '<start> Do what ? <end>',
#  'L607': '<start> How d you do it ? <end>',
#  'L606': '<start> A deal s a deal . <end>',
#  'L605': '<start> It s about time . <end>',
#  'L358': '<start> Forget her sister , then . <end>',
#  'L357': '<start> Forget it . <end>',
#  'L356': '<start> A hundred bucks a date . <end>',
#  'L355': '<start> What ? <end>',
#  'L354': '<start> I just upped my price <end>',
#  'L352': '<start> I got her under control . She just acts crazed in public to keep up the image . <end>',
#  'L351': '<start> Watching the bitch trash my car doesn t count as a date . <end>',
#  'L350': '<start> I m on it <end>',
#  'L349': '<start> When I shell out fifty , I expect results . <end>',
#  'L301': '<start> Fifty , and you ve got your man . <end>',
#  'L300': '<start> Take it or leave it . This isn t a negotiation . <end>',
#  'L299': '<start> Fine , thirty . <end>',
#  'L298': '<start> I can t take a girl like that out on twenty bucks . <end>',
#  'L297': '<start> How much ? <end>',
#  'L296': '<start> I can t date her sister until that one gets a boyfriend . And that s the catch . She doesn t want a boyfriend . <end>',
#  'L295': '<start> You re gonna pay me to take out some girl ? <end>',
#  'L294': '<start> You got it , Verona . I pick up the tab , you do the honors . <end>',
#  'L292': '<start> But you d go out with her if you had the cake ? <end>',
#  'L291': '<start> You need money to take a girl out <end>',
#  'L290': '<start> You just said <end>',
#  'L289': '<start> Sure , Sparky . I ll get right on it . <end>',
#  'L288': '<start> Yeah , whatever . I want you to go out with her . <end>',
#  'L287': '<start> Two legs , nice rack . <end>',
#  'L286': '<start> What do you think ? <end>',
#  'L285': '<start> Yeah <end>',
#  'L509': '<start> Hey it s all for the higher good right ? <end>',
#  'L508': '<start> You better not fuck this up . I m heavily invested . <end>',
#  'L505': '<start> What ? We took bathes together when we were kids . <end>',
#  'L504': '<start> You and Verona ? <end>',
#  'L503': '<start> Uh , yeah . We re old friend <end>',
#  'L502': '<start> I hear you re helpin Verona . <end>',
#  'L240': '<start> So what you need to do is recruit a guy who ll go out with her . Someone who s up for the job . <end>',
#  'L239': '<start> Does this conversation have a purpose ? <end>',
#  'L238': '<start> But she can t go out with you because her sister is this insane head case and no one will go out with her . right ? <end>',
#  'L236': '<start> We re not . <end>',
#  'L235': '<start> Well , actually , I thought I d run an idea by you . You know , just to see if you re interested . <end>',
#  'L234': '<start> We don t chat . <end>',
#  'L233': '<start> Nope just came by to chat <end>',
#  'L232': '<start> Are you lost ? <end>',
#  'L231': '<start> Hey . <end>',
#  'L949': '<start> Oh , honey tell me we haven t progressed to full on hallucinations . <end>',
#  'L948': '<start> William he asked me to meet him here . <end>',
#  'L947': '<start> Who ? <end>',
#  'L946': '<start> Have you seen him ? <end>',
#  'L755': '<start> Oh , good . Something new and different for us . <end>',
#  'L754': '<start> You re looking at this from the wrong perspective . We re making a statement . <end>',
#  'L753': '<start> Okay , okay , we won t go . It s not like I have a dress anyway <end>',
#  'L752': '<start> Listen to you ! You sound like Betty , all pissed off because Archie is taking Veronica . <end>',
#  'L751': '<start> Well , I guess we re not , since we don t have dates . <end>',
#  'L750': '<start> Can you even imagine ? Who the hell would go to this a bastion of commercial excess ? <end>',
#  'L721': '<start> I got drunk . I puked . I got rejected . It was big fun . <end>',
#  'L720': '<start> You didn t <end>',
#  'L719': '<start> I did Bianca a favor and it backfired . <end>',
#  'L718': '<start> You didn t have a choice ? Where s Kat and what have you done with her ? <end>',
#  'L717': '<start> I didn t have a choice . <end>',
#  'L716': '<start> You went to the party ? I thought we were officially opposed to suburban social activity . <end>',
#  'L491': '<start> Who cares ? <end>',
#  'L490': '<start> What d he say ? <end>',
#  'L448': '<start> No fear . <end>',
#  'L447': '<start> You think this ll work ? <end>',
#  'L254': '<start> If I was Bianca , it would be , Any school you want , precious . Don t forget your tiara . <end>',
#  'L253': '<start> Does it matter ? <end>',
#  'L252': '<start> I appreciate your efforts toward a speedy death , but I m consuming . Do you mind ? <end>',
#  'L251': '<start> Neither has his heterosexuality . <end>',
#  'L250': '<start> That s never been proven <end>',
#  'L249': '<start> William didn t even go to high school <end>',
#  'L248': '<start> William would never have gone to a state school . <end>',
#  'L247': '<start> So he has this huge raging fit about Sarah Lawrence and insists that I go to his male dominated , puking frat boy , number one golf team school . I have no say at all . <end>',
#  'L152': '<start> You could always go with me . I m sure William has some friends . <end>',
#  'L151': '<start> The people at this school are so incredibly foul . <end>',
#  'L134': '<start> But imagine the things he d say during sex . <end>',
#  'L133': '<start> I realize that the men of this fine institution are severely lacking , but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions . You re venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy . <end>',
#  'L132': '<start> An attempted slit . <end>',
#  'L131': '<start> What s this ? <end>',
#  'L130': '<start> Just a little . <end>',
#  'L129': '<start> Mandella , eat . Starving yourself is a very slow way to die . <end>',
#  'L128': '<start> Block E ? <end>',
#  'L127': '<start> He always look so <end>',
#  'L126': '<start> I m sure he s completely incapable of doing anything that interesting . <end>',
#  'L125': '<start> That s Pat Verona ? The one who was gone for a year ? I heard he was doing porn movies . <end>',
#  'L124': '<start> Patrick Verona Random skid . <end>',
#  'L123': '<start> Who s that ? <end>',
#  'L1043': '<start> Don t you even dare . . . <end>',
#  'L1042': '<start> Oh , Bianca ? Can you get me my freshman yearbook ? <end>',
#  'L1041': '<start> Because I like to torture you . <end>',
#  'L1040': '<start> Why is my veggie burger the only burnt object on this grill ? <end>',
#  'L1035': '<start> Yeah , but then I fucked up . I fell for her . <end>',
#  'L1034': '<start> Is that right ? <end>',
#  'L1033': '<start> Besides , I had some extra cash . Some asshole paid me to take out a really great girl . <end>',
#  'L1032': '<start> I thought you could use it . When you start your band . <end>',
#  'L1031': '<start> A Fender Strat . You bought this ? <end>',
#  'L977': '<start> I didn t care about the money . <end>',
#  'L976': '<start> Really ? What was it like ? A down payment now , then a bonus for sleeping with me ? <end>',
#  'L975': '<start> It wasn t like that . <end>',
#  'L974': '<start> You were paid to take me out ! By the one person I truly hate . I knew it was a set up ! <end>',
#  'L973': '<start> Wait I . <end>',
#  'L961': '<start> It gets worse you still have your freshman yearbook ? <end>',
#  'L960': '<start> That s completely adorable ! <end>',
#  'L959': '<start> That s where I was last year . She d never lived alone my grandfather died I stayed with her . I wasn t in jail , I don t know Marilyn Manson , and I ve never slept with a Spice Girl . I spent a year sitting next to my grandma on the couch watching Wheel of Fortune . End of story . <end>',
#  'L958': '<start> What ? <end>',
#  'L957': '<start> My grandmother s . <end>',
#  'L940': '<start> Look , I m sorry that I questioned your motives . I was wrong . <end>',
#  'L939': '<start> Oh huh <end>',
#  'L938': '<start> It s just something I had . You know <end>',
#  'L937': '<start> It s Scurvy s . His date got convicted . Where d you get the dress ? <end>',
#  'L936': '<start> How d you get a tux at the last minute ? <end>',
#  'L857': '<start> Nothing ! There s nothing in it for me . Just the pleasure of your company . <end>',
#  'L856': '<start> Answer the question , Patrick <end>',
#  'L855': '<start> You need therapy . Has anyone ever told you that ? <end>',
#  'L854': '<start> You tell me . <end>',
#  'L853': '<start> So I have to have a motive to be with you ? <end>',
#  'L852': '<start> Create a little drama ? Start a new rumor ? What ? <end>',
#  'L848': '<start> Because I don t want to . It s a stupid tradition . <end>',
#  'L847': '<start> Why not ? <end>',
#  'L846': '<start> No , I won t go with you <end>',
#  'L845': '<start> No what ? <end>',
#  'L844': '<start> No . <end>',
#  'L843': '<start> You know what I mean <end>',
#  'L842': '<start> Is that a request or a command ? <end>',
#  'L841': '<start> Go to the prom with me <end>',
#  'L840': '<start> You re amazingly self assured . Has anyone ever told you that ? <end>',
#  'L839': '<start> No one else knows <end>',
#  'L838': '<start> What ? <end>',
#  'L837': '<start> You re sweet . And sexy . And completely hot for me . <end>',
#  'L836': '<start> No something real . Something no one else knows . <end>',
#  'L835': '<start> I hate peas . <end>',
#  'L834': '<start> Tell me something true . <end>',
#  'L832': '<start> I know the porn career s a lie . <end>',
#  'L831': '<start> Hearsay . <end>',
#  'L830': '<start> The duck ? <end>',
#  'L829': '<start> Fallacy . <end>',
#  'L828': '<start> State trooper ? <end>',
#  'L825': '<start> For . . . ? <end>',
#  'L824': '<start> You up for it ? <end>',
#  'L823': '<start> You never disappointed me . <end>',
#  'L822': '<start> How ? <end>',
#  'L821': '<start> Then you screwed up <end>',
#  'L820': '<start> Something like that <end>',
#  'L819': '<start> So if you disappoint them from the start , you re covered ? <end>',
#  'L818': '<start> I don t like to do what people expect . Then they expect it all the time and they get disappointed when you change . <end>',
#  'L817': '<start> Yes <end>',
#  'L816': '<start> Acting the way we do . <end>',
#  'L815': '<start> So what s your excuse ? <end>',
#  'L814': '<start> Yeah , well , don t let it get out <end>',
#  'L813': '<start> A soft side ? Who knew ? <end>',
#  'L812': '<start> I dazzled him with my wit <end>',
#  'L811': '<start> So how d you get Chapin to look the other way ? <end>',
#  'L810': '<start> Good call . <end>',
#  'L809': '<start> I figured it had to be something ridiculous to win your respect . And piss you off . <end>',
#  'L808': '<start> The Partridge Family ? <end>',
#  'L806': '<start> Maybe . <end>',
#  'L805': '<start> You want me to climb up and show you how to get down ? <end>',
#  'L804': '<start> Forget it . I m stayin . <end>',
#  'L803': '<start> Put your right foot there <end>',
#  'L802': '<start> Try lookin at it from this angle <end>',
#  'L801': '<start> C mon . It s not that bad <end>',
#  'L800': '<start> I guess I never told you I m afraid of heights . <end>',
#  'L799': '<start> Look up , sunshine <end>',
#  'L798': '<start> He left ! I sprung the dickhead and he cruised on me . <end>',
#  'L774': '<start> Other than my upchuck reflex ? Nothing . <end>',
#  'L773': '<start> So what did I have an effect on ? <end>',
#  'L772': '<start> Don t for one minute think that you had any effect whatsoever on my panties . <end>',
#  'L771': '<start> Unwelcome ? I guess someone still has her panties in a twist . <end>',
#  'L770': '<start> Unwelcome . <end>',
#  'L769': '<start> Wholesome . <end>',
#  'L768': '<start> Pleasant ? <end>',
#  'L767': '<start> You re so <end>',
#  'L766': '<start> I heard there was a poetry reading . <end>',
#  'L765': '<start> What are you doing here ? <end>',
#  'L764': '<start> Excuse me , have you seen The Feminine Mystique ? I lost my copy . <end>',
#  'L690': '<start> No offense , but you re sister is without . I know everyone likes her and all , but . <end>',
#  'L689': '<start> BIANCA <end>',
#  'L688': '<start> Who ? <end>',
#  'L687': '<start> He just wants me to be someone I m not . <end>',
#  'L686': '<start> So what s up with your dad ? He a pain in the ass ? <end>',
#  'L684': '<start> I m gettin there <end>',
#  'L683': '<start> Oh , so now you think you know me ? <end>',
#  'L682': '<start> You don t strike me as the type that would ask permission . <end>',
#  'L681': '<start> My father wouldn t approve of that that <end>',
#  'L680': '<start> Start a band ? <end>',
#  'L679': '<start> This . <end>',
#  'L678': '<start> Do what ? <end>',
#  'L677': '<start> I should do this . <end>',
#  'L676': '<start> Why d you lie ? <end>',
#  'L675': '<start> Then why d you ask ? <end>',
#  'L674': '<start> No , you weren t <end>',
#  'L673': '<start> Maybe . <end>',
#  'L672': '<start> Were you in jail ? <end>',
#  'L671': '<start> Busy <end>',
#  'L670': '<start> When you were gone last year where were you ? <end>',
#  'L669': '<start> But it s Gigglepuss I know you like them . I saw you there . <end>',
#  'L668': '<start> And I m in control of it . <end>',
#  'L651': '<start> What ? <end>',
#  'L650': '<start> Kat ! Wake up ! <end>',
#  'L646': '<start> You know what they say <end>',
#  'L645': '<start> I thought you were above all that <end>',
#  'L644': '<start> Hey man . . . You don t think I can be cool ? You don t think I can be laid back like everyone else ? <end>',
#  'L643': '<start> I know . It d have to be a pretty big deal to get you to mainline tequila . You don t seem like the type . <end>',
#  'L642': '<start> I hate him . <end>',
#  'L641': '<start> Dorsey . <end>',
#  'L640': '<start> Who ? <end>',
#  'L639': '<start> Why d you let him get to you ? <end>',
#  'L636': '<start> Just let me sit down . <end>',
#  'L635': '<start> See that ? Who needs affection when I ve got blind hatred ? <end>',
#  'L634': '<start> Like you could find one <end>',
#  'L633': '<start> Because then I d have to start taking out girls who like me . <end>',
#  'L632': '<start> Why ? <end>',
#  'L631': '<start> Sure , I do <end>',
#  'L630': '<start> You don t care if I die <end>',
#  'L629': '<start> I told you <end>',
#  'L628': '<start> Why re you doing this ? <end>',
#  'L627': '<start> Leave it to you to use big words when you re shitfaced . <end>',
#  'L626': '<start> This is so patronizing . <end>',
#  'L616': '<start> What if you have a concussion ? My dog went to sleep with a concussion and woke up a vegetable . Not that I could tell the difference . <end>',
#  'L615': '<start> I know , just let me sleep <end>',
#  'L614': '<start> Uh , uh . You lie down and you ll go to sleep <end>',
#  'L613': '<start> I just need to lie down for awhile <end>',
#  'L612': '<start> You re not okay . <end>',
#  'L611': '<start> I m fine . I m <end>',
#  'L610': '<start> Okay ? <end>',
#  'L567': '<start> Funny , you re the only one <end>',
#  'L566': '<start> I say , do what you wanna do . <end>',
#  'L565': '<start> I m getting trashed , man . Isn t that what you re supposed to do at a party ? <end>',
#  'L564': '<start> What s this ? <end>',
#  'L483': '<start> Why , don t you ? <end>',
#  'L482': '<start> You know who The Raincoats are ? <end>',
#  'L481': '<start> You know , these guys are no Bikini Kill or The Raincoats , but they re right up there . <end>',
#  'L477': '<start> Do you mind ? You re sort of ruining it for me . <end>',
#  'L476': '<start> That s what you want , isn t it ? <end>',
#  'L475': '<start> Excuse me ? <end>',
#  'L474': '<start>  <end>',
#  'L473': '<start> hey . Great show , huh ? <end>',
#  'L334': '<start> Depends on the topic . My fenders don t really whip me into a verbal frenzy . <end>',
#  'L333': '<start> You re not a big talker , are you ? <end>',
#  'L332': '<start> Hi <end>',
#  'L331': '<start> I was in the laundromat . I saw your car . Thought I d say hi . <end>',
#  'L330': '<start> Are you following me ? <end>',
#  'L328': '<start> Seven thirty ? <end>',
#  'L327': '<start> You covered in my vomit . <end>',
#  'L326': '<start> Come on the ponies , the flat beer , you with money in your eyes , me with my hand on your ass . <end>',
#  'L325': '<start> And why would I do that ? <end>',
#  'L324': '<start> Then say you ll spend Dollar Night at the track with me . <end>',
#  'L323': '<start> I don t really think you warrant that strong an emotion . <end>',
#  'L322': '<start> You hate me don t you ? <end>',
#  'L313': '<start> I know a lot more than that <end>',
#  'L312': '<start> Like where ? The Eleven on Burnside ? Do you even know my name , screwboy ? <end>',
#  'L311': '<start> The night I take you to places you ve never been before . And back . <end>',
#  'L310': '<start> Oh , right . Friday . <end>',
#  'L309': '<start> Pick you up Friday , then <end>',
#  'L307': '<start> My mission in life . <end>',
#  'L306': '<start> There s a way to get a guy s attention . <end>',
#  'L305': '<start> Sweating like a pig , actually . And yourself ? <end>',
#  'L304': '<start> I mean Wo man . How ya doin ? <end>',
#  'L1000': '<start> Oh , Christ . Don t tell me you ve changed your mind . I already sent em a check . <end>',
#  'L999': '<start> When I go ? <end>',
#  'L998': '<start> You know , fathers don t like to admit that their daughters are capable of running their own lives . It means we ve become spectators . Bianca still lets me play a few innings . You ve had me on the bleachers for years . When you go to Sarah Lawrence , I won t even be able to watch the game . <end>',
#  'L997': '<start> No impressed . <end>',
#  'L996': '<start> What s the matter ? Upset that I rubbed off on her ? <end>',
#  'L995': '<start> Bianca did what ? <end>',
#  'L994': '<start> The part where Bianca beat the hell out of some guy . <end>',
#  'L993': '<start> Which parts ? <end>',
#  'L992': '<start> Parts of it . <end>',
#  'L991': '<start> So tell me about this dance . Was it fun ? <end>',
#  'L990': '<start> No , Daddy . <end>',
#  'L989': '<start> I don t understand the allure of dehydrated food . Is this something I should be hip to ? <end>',
#  'L988': '<start> Funny . <end>',
#  'L987': '<start> Yeah . She left with some bikers Big ones . Full of sperm . <end>',
#  'L986': '<start> Was that your sister ? <end>',
#  'L347': '<start> I want to go to an East Coast school ! I want you to trust me to make my own choices . I want <end>',
#  'L346': '<start> You re eighteen . You don t know what you want . You won t know until you re forty five and you don t have it . <end>',
#  'L345': '<start> So what I want doesn t matter ? <end>',
#  'L344': '<start> As a parent , that s my right <end>',
#  'L343': '<start> Because you re making decisions for me . <end>',
#  'L342': '<start> Why can t we agree on this ? <end>',
#  'L341': '<start> I thought you were punishing me . <end>',
#  'L340': '<start> Is this about Sarah Lawrence ? You punishing me ? <end>',
#  'L339': '<start> Then tell them I had a seizure . <end>',
#  'L338': '<start> My insurance does not cover PMS <end>',
#  'L185': '<start> Enough ! <end>',
#  'L184': '<start> This from someone whose diary is devoted to favorite grooming tips ? <end>',
#  'L174': '<start> You decided . <end>',
#  'L173': '<start> I thought we decided you were going to school here . At U of . <end>',
#  'L172': '<start> I know . <end>',
#  'L1018': '<start> Just smack her now . <end>',
#  'L1017': '<start> Am I supposed to feel better ? Like , right now ? Or do I have some time to think about it ? <end>',
#  'L109': '<start> No . I believe heinous bitch is the term used most often . <end>',
#  'L108': '<start> Tempestuous ? <end>',
#  'L107': '<start> The point is Kat people perceive you as somewhat . <end>',
#  'L106': '<start> I still maintain that he kicked himself in the balls . I was merely a spectator . <end>',
#  'L105': '<start> Well , yes , compared to your other choices of expression this year , today s events are quite mild . By the way , Bobby Rictor s gonad retrieval operation went quite well , in case you re interested . <end>',
#  'L104': '<start> Expressing my opinion is not a terrorist action . <end>',
#  'L103': '<start> Katarina Stratford . My , my . You ve been terrorizing Ms . Blaise again . <end>',
#  'L738': '<start> Yeah . <end>',
#  'L737': '<start> Kat a fan , too ? <end>',
#  'L736': '<start> Right . <end>',
#  'L735': '<start> Macbeth , right ? <end>',
#  'L733': '<start> Oh yeah . <end>',
#  'L732': '<start> You think ? <end>',
#  'L731': '<start> Yeah . I guess . <end>',
#  'L730': '<start> Cool pictures . You a fan ? <end>',
#  'L729': '<start> Hi . <end>',
#  'L728': '<start> Hey there . Tired of breathing ? <end>',
#  'L777': '<start> Man don t say shit like that to me . People can hear you . <end>',
#  'L776': '<start> Sweet love , renew thy force ! <end>',
#  'L775': '<start> You were right . She s still pissed . <end>',
#  'L724': '<start> No I ve got a sweet payin job that I m about to lose . <end>',
#  'L723': '<start> So you got cozy with she who stings ? <end>',
#  'L437': '<start> I m likin you guys better <end>',
#  'L436': '<start> I prefer to think of it simply as an alternative to what the law allows . <end>',
#  'L429': '<start> Yeah . <end>',
#  'L428': '<start> Ever been to Club Skunk ? <end>',
#  'L421': '<start> Just for now . <end>',
#  'L420': '<start> Are you telling me I m a non smoker ? <end>',
#  'L415': '<start> Good enough . <end>',
#  'L414': '<start> What ? ! <end>',
#  'L384': '<start> We re your guys . <end>',
#  'L383': '<start> You two are gonna help me tame the wild beast ? <end>',
#  'L382': '<start> Patrick , Pat , you re not looking at the big picture . Joey s just a pawn . We set this whole thing up so Cameron can get the girl . <end>',
#  'L381': '<start> So Dorsey can get the girl ? <end>',
#  'L380': '<start> That s where we can help you . With Kat . <end>',
#  'L379': '<start> Dorsey can plow whoever he wants . I m just in this for the cash . <end>',
#  'L378': '<start> I think I speak correctly when I say that Cameron s love is pure . Purer than say Joey Dorsey s . <end>',
#  'L377': '<start> What is it with this chick ? She have three tits ? <end>',
#  'L376': '<start> The situation is , my man Cameron here has a major jones for Bianca Stratford . <end>',
#  'L375': '<start> What plan ? <end>',
#  'L373': '<start> Whatever the hell it is you re standin there waitin to say . <end>',
#  'L372': '<start> What ? <end>',
#  'L371': '<start> Say it <end>',
#  'L512': '<start> See you next week ! <end>',
#  'L511': '<start> You re completely demented . <end>',
#  'L264': '<start> Well , you know there s the prestige of the job title . and the benefits package is pretty good . <end>',
#  'L263': '<start> You weren t abused , you aren t stupid , and as far as I can tell , you re only slightly psychotic so why is it that you re such a fuck up ? <end>',
#  'L262': '<start> What s to discuss ? <end>',
#  'L261': '<start> Why don t we discuss your driving need to be a hemorrhoid ? <end>',
#  'L259': '<start> I m at a loss , then . What should we talk about ? Your year of absence ? <end>',
#  'L258': '<start> Touch of the flu . <end>',
#  'L257': '<start> I don t understand , Patrick . You haven t done anything asinine this week . Are you not feeling well ? <end>',
#  'L62': '<start> With the teeth of your zipper ? <end>',
#  'L61': '<start> It was a bratwurst . I was eating lunch . <end>',
#  'L60': '<start> It says here you exposed yourself to a group of freshmen girls . <end>',
#  'L59': '<start> I missed you . <end>',
#  'L933': '<start> That s what I thought <end>',
#  'L932': '<start> Absolutely not . <end>',
#  'L931': '<start> Did I have anything to say about it ? <end>',
#  'L930': '<start> Your daughters went to the prom . <end>',
#  'L929': '<start> What just happened ? <end>',
#  'L927': '<start> But who what ? <end>',
#  'L926': '<start> Have a great time , honey ! <end>',
#  'L918': '<start> Dr . Ruth ? <end>',
#  'L917': '<start> What do you wanna watch ? We ve got crap , crap , crap or crap <end>',
#  'L887': '<start> Kissing ? Is that what you think happens ? Kissing isn t what keeps me up to my elbows in placenta all day . <end>',
#  'L886': '<start> They ll dance , they ll kiss , they ll come home . Let her go . <end>',
#  'L877': '<start> Pirate no question . <end>',
#  'L876': '<start> Would you rather be ravished by a pirate or a British rear admiral ? <end>',
#  'L193': '<start> You re not helping . <end>',
#  'L192': '<start> Tumescent ! <end>',
#  'L191': '<start> Jesus ! Can a man even grab a sandwich before you women start dilating ? <end>',
#  'L171': '<start> Sarah Lawrence is on the other side of the country . <end>',
#  'L170': '<start> What s a synonym for throbbing ? <end>',
#  'L162': '<start> Make anyone cry today ? <end>',
#  'L161': '<start> In the microwave . <end>',
#  'L2181': '<start> Can t be that far , I say . Also , I don t like the smell of the sea around here . Smells like a cunt . Bad sign . <end>',
#  'L2180': '<start> We left three weeks ago , Alonso . Can t be that near . <end>',
#  'L2179': '<start> We should have seen land . <end>',
#  'L2177': '<start> We ll all go crazy . <end>',
#  'L2176': '<start> He s the devil s child . <end>',
#  'L2175': '<start> With a face like that ? I don t want you looking at me . You hear ? <end>',
#  'L2174': '<start> Ah , leave him alone . He s doing no harm . <end>',
#  'L2173': '<start> What are you listening to , chicken ass ? <end>',
#  'L2172': '<start> You ll be drinking your own piss . For the glory of Spain . and Admiral Colon . ! Bastard ! <end>',
#  'L2171': '<start> The water s going putrid in the barrels . <end>',
#  'L2170': '<start> I never seen heat like this ! Not even in Las Minas ! <end>',
#  'L2025': '<start> IF GOD WILLS IT ! <end>',
#  'L2024': '<start> Asia can be found to the west and I will prove it . <end>',
#  'L2023': '<start> Blind faith is what I consider heresy ! <end>',
#  'L2022': '<start> Don t you realize your words could be considered heretical ? <end>',
#  'L2020': '<start> Did He not choose a carpenter s son to reveal Himself to the world ? <end>',
#  'L2019': '<start> If God intended our proximity to Asia , do you believe he would have waited for you to show it to the world ? <end>',
# ...
#  'L2410': '<start> You never learned how to speak my language . <end>',
#  'L2409': '<start> Utapan , won t you speak to me ? You used to know how to speak to me . <end>',
#  'L2394': '<start> You did the same to your God ! <end>',
#  'L2393': '<start> You have to find them , Utapan . Look what they did ! <end>',
#  'L2343': '<start> Ask him if he will help . <end>',
#  'L2342': '<start> He understands . <end>',
#  'L2341': '<start> We will work with his people . We want peace . Ask the Chief if he understands ? <end>',
#  'L2260': '<start> He has medicine . Tell him we admire his people . <end>',
#  'L2259': '<start> Chief says . <end>',
#  'L2258': '<start> . and also to bring medicine . <end>',
#  'L2257': '<start> Chief says he has a God . <end>',
#  'L2256': '<start> To bring the word of God . <end>',
#  'L2255': '<start> Why ? <end>',
#  'L2254': '<start> Thousands . <end>',
#  'L2253': '<start> Chief says how many ? <end>',
#  'L2251': '<start> Tell him his country is very beautiful . Tell him we are leaving men here to build a fort . <end>',
#  'L2250': '<start> Chief knows . <end>',
#  'L2249': '<start> Tell the Chief we thank him . <end>',
#  'L2248': '<start> You come ! You speak first ! <end>',
#  'L2239': '<start> Island . Far . <end>',
#  'L2238': '<start> What is it ? A tribe ? An island ? <end>',
#  'L2237': '<start> Say not here ! Cuba ! <end>',
#  'L2535': '<start> I don t know . I have the impression that I didn t change that much . I still can t accept the world as it is ! <end>',
#  'L2534': '<start> Oh ? So you are a new man ? <end>',
#  'L2533': '<start> New worlds create new people . <end>',
#  'L2532': '<start> I knew you would . <end>',
#  'L2531': '<start> I have to disagree . <end>',
#  'L2526': '<start> You ll always be older than me , Father . <end>',
#  'L2525': '<start> I suppose we re both old men now . <end>',
#  'L2145': '<start> Give me absolution . <end>',
#  'L2144': '<start> I believed in you . <end>',
#  'L2143': '<start> You are bound by an oath , Father . <end>',
#  'L2142': '<start> My son , my son . Your certitudes are sometimes frightening . Christopher , you must speak to them . And if you don t I will . <end>',
#  'L2141': '<start> If I tell them , they won t follow me . You know that I am right , Father . You trust me . <end>',
#  'L2140': '<start> May God forgive you . ! You must tell them ! You must tell your men ! <end>',
#  'L2139': '<start> I am not sure . It could be twice the distance . <end>',
#  'L2138': '<start> How long ? <end>',
#  'L2137': '<start> I lied . The journey will be longer than I said . <end>',
#  'L2136': '<start> What are you saying ? <end>',
#  'L2135': '<start> Father , I have betrayed my family . I betrayed my men . And I betrayed you . <end>',
#  'L2134': '<start> I am listening , my son . <end>',
#  'L2133': '<start> Forgive me , Father . For I have sinned . <end>',
#  'L2132': '<start> In Nomine Patris et Filius , et Spiritus Sancti . <end>',
#  'L2046': '<start> Colon ! Don t ! <end>',
#  'L2045': '<start> All of them ! Just lies ! <end>',
#  'L2042': '<start> Damn all of you ! You all set up theories based on what ? You never leave the safety of your studies ! Go out ! Find out what the world is about and then tell me something I can listen to ! <end>',
#  'L2041': '<start> Colon ! <end>',
#  'L2040': '<start> Damn God ! <end>',
#  'L2039': '<start> If God intends you to go , then you will go . <end>',
#  'L2038': '<start> Wait ! I ve waited seven years already ! How much longer do you want me to wait ? <end>',
#  'L2037': '<start> You mustn t give way to despair . You must wait . <end>',
#  'L1969': '<start> Only God knows the meaning of such words , my son . <end>',
#  'L1968': '<start> I ve been contradicted all my life . Eternity ! <end>',
#  'L1967': '<start> You get so carried away when you are being contradicted ! <end>',
#  'L1966': '<start> Passion is something one cannot control ! <end>',
#  'L1965': '<start> Father Marchena ! <end>',
#  'L1964': '<start> I ll try to remember that , Marchena . <end>',
#  'L1963': '<start> Two minutes . and already you re a dead man . Don t let passion overwhelm you , Colon . <end>',
#  'L1962': '<start> So was Christ ! <end>',
#  'L1961': '<start> Esdras is a Jew . <end>',
#  'L1960': '<start> The calculations of Toscanelli Marin de Tyr , Esdras . <end>',
#  'L1959': '<start> How can you be so certain ? <end>',
#  'L1958': '<start> Ignorance ! I believe the Indies are no more than leagues west of the Canary Islands . <end>',
#  'L1957': '<start> How can you be so certain ? The Ocean is said to be infinite . <end>',
#  'L1952': '<start> To open a new route to Asia . At the moment there are only two ways of reaching it . <end>',
#  'L1951': '<start> Why do you wish to sail west ? <end>',
#  'L1950': '<start> With some difficulty . I had to promise them you were not a total fool . <end>',
#  'L1949': '<start> How did you manage it ? <end>',
#  'L1948': '<start> That s what it says . <end>',
#  'L1947': '<start> God . That s in a week ! <end>',
#  'L1943': '<start> Father , I am doing what I think is the best for him . And he has the teacher I would have chosen for myself . <end>',
#  'L1942': '<start> Diego is a bright boy a pleasure to teach but so serious . Brothers should be raised together , Colon . Even brothers from different mothers . <end>',
#  'L2459': '<start> Your Majesty some men are content to read about things . I must see them with my own eyes . I cannot be other than I am . <end>',
#  'L2458': '<start> There is one thing I d like to understand . Why do you want to go back , after all this ? <end>',
#  'L2457': '<start> Thank you . <end>',
#  'L2456': '<start> But without your brothers . Nor are you to return to Santo Domingo or any of the other colonies . You may explore the continent . <end>',
#  'L2280': '<start> They come and go as naked as the day God created them . <end>',
#  'L2279': '<start> Do they have such thoughts ? <end>',
#  'L2086': '<start> Thirty seven , Your Majesty . And you ? <end>',
#  'L2085': '<start> How old are you , Senor Colon ? <end>',
#  'L2082': '<start> A woman ? <end>',
#  'L2081': '<start> I know what I see . I see someone who doesn t accept the world as it is . Who s not afraid . I see a women who thinks . What if ? . <end>',
#  'L2080': '<start> You show no inclination to speak otherwise ! <end>',
#  'L2079': '<start> May I speak freely ? <end>',
#  'L2077': '<start> Surely you can do anything you want . <end>',
#  'L2076': '<start> I cannot ignore the verdict of my council . <end>',
#  'L2075': '<start> That she was impregnable . <end>',
#  'L2074': '<start> What did they say about Granada before today ? <end>',
#  'L2073': '<start> The ocean is uncrossable ? <end>',
#  'L2072': '<start> No more than the woman who said she would take Granada from the Moors . <end>',
#  'L2071': '<start> I should not even be listening to you , since my council said no . But Santangel tells me you are a man of honor and sincerity . And Sanchez , that you are not a fool . <end>',
#  'L2389': '<start> You will regret this . <end>',
#  'L2388': '<start> You ll be held in detention , deprived of your privileges and possessions . Until you are returned to Spain where you will be judged . Have you anything to say ? <end>',
#  'L2387': '<start> Savagery is what monkeys understand . <end>',
#  'L2386': '<start> In one act of brutality , you have created chaos . Tribes who were fighting each other are now joining forces against us ! All that because of your criminal savagery ! <end>',
#  'L2348': '<start> You did not hear me , Don Colon . Not my horse . <end>',
#  'L2347': '<start> Don Moxica we all have to work . <end>',
#  'L2346': '<start> My horse doesn t work . <end>',
#  'L2345': '<start> We can t raise the wheel without it . <end>',
#  'L2333': '<start> We came here to stay ! To build ! Not to start a crusade . In this forest , there is enough danger to sweep us away in days ! So we will be brave and swallow our grief . And in the name of those who died , we will accomplish what we came for . <end>',
#  'L2332': '<start> We don t need to know . <end>',
#  'L2331': '<start> You want a war ? Fine . We are a thousand . They outnumber us by ten ! Who will you kill ? Which tribe ? <end>',
#  'L2329': '<start> If you want to keep your head on your shoulders , you ll do as I say . <end>',
#  'L2328': '<start> We lost cousins , friends . We will wash this in blood . <end>',
#  'L2278': '<start> The Indians have no such word , Don Moxica . <end>',
#  'L2277': '<start> And you say this is an Indian vice ? By God ! I don t see any kind of pleasure that would make this a sin . <end>',
#  'L2492': '<start> We can t be . <end>',
#  'L2491': '<start> He s drawing an isthmus . He s saying we re on an isthmus . <end>',
#  'L2490': '<start> What s he doing ? <end>',
#  'L2165': '<start> Twenty eight . <end>',
#  'L2164': '<start> What do you read ? <end>',
#  'L2160': '<start> Come over here . <end>',
#  'L2159': '<start> Well , I surely know what a quadrant is ! But I ve never seen it used at night before . <end>',
#  'L2158': '<start> And what do you think Mendez ? <end>',
#  'L2157': '<start> Well . It s the men , Sir . They wonder how you know our position . We ve lost sight from land days ago . <end>',
#  'L2155': '<start> God be with us admiral . <end>',
#  'L2154': '<start> Due west , Captain Mendez . And may God be with us . <end>',
#  'L2211': '<start> You re right . Let the men decide . <end>',
#  'L2210': '<start> You tell that to them ! <end>',
#  'L2209': '<start> Pinzon , Pinzon . All we can do now is go forward ! Think about that ! <end>',
#  'L2208': '<start> You bloody . <end>',
#  'L2207': '<start> You never did . You did all the talking for both of us , remember ? <end>',
#  'L2206': '<start> Jesus Maria ! I should have never listened to you ! <end>',
#  'L2205': '<start> And then what ? Half of the water has gone , the rest is nearly putrid ! You know that ! <end>',
#  'L2204': '<start> You don t know anything ! Listen Colon , these are my ships , right ? So I m telling you we re turning back ! <end>',
#  'L2203': '<start> The land is there . I know it ! <end>',
#  'L2202': '<start> We re lost ! <end>',
#  'L2201': '<start> You think I don t know that ? <end>',
#  'L2200': '<start> We re on the verge of a mutiny , Colon ! <end>',
#  'L2199': '<start> We have to keep the hopes of these men alive ! <end>',
#  'L2198': '<start> You must be mad . ! <end>',
#  'L2197': '<start> Six days ago , yes . <end>',
#  'L2196': '<start> You lied ! You cheated ! We re way past leagues ! <end>',
#  'L2065': '<start> Immediately . <end>',
#  'L2064': '<start> Where can I meet this man ? <end>',
#  'L2462': '<start> Because he is not afraid of me . <end>',
#  'L2461': '<start> Then why ? <end>',
#  'L2460': '<start> I know , I should not tolerate his impertinence . <end>',
#  'L2419': '<start> And who would you think of , for such a task ? <end>',
#  'L2418': '<start> He must be replaced . <end>',
#  'L2417': '<start> Then , what do you suggest , Don Sanchez ? <end>',
#  'L2415': '<start> Is this true , Brother Buyl ? <end>',
#  'L2414': '<start> . But there is worse . He ordered the execution of five members of the nobility . <end>',
#  'L2377': '<start> We weren t expecting immediate profits , were we ? We must have faith . We must give time for time . <end>',
#  'L2376': '<start> Every ship returns with a cargo of sick and dying . But with no gold ! The new world proves expensive , Your Majesty . <end>',
#  'L2116': '<start> Yes . It would be a pity , wouldn t it ? Call him back ! <end>',
#  'L2115': '<start> . Into a monk . <end>',
#  'L2113': '<start> Never , Your Majesty . Although . <end>',
#  'L2112': '<start> You were right , Don Sanchez . His demands could never be granted . <end>',
#  'L1931': '<start> Yes , Your Majesty . <end>',
#  'L1930': '<start> Is that the man I knew , Treasurer Sanchez ? <end>',
#  'L3546': '<start> Officers , there s your killer , do your duty , arrest him ! <end>',
#  'L3545': '<start> . so we kill someone famous and if we are caught , we are sent to mental hospital . <end>',
#  'L3497': '<start> I don t think it s abuse , I think it s torture . <end>',
#  'L3496': '<start> I m abused . Don t you think ? <end>',
#  'L3493': '<start> Can I see your back ? <end>',
#  'L3492': '<start> Out on my back when I was a small boy . <end>',
#  'L3491': '<start> Your father put cigarettes out on you ? <end>',
#  'L3490': '<start> That s what he did to me . He put cigarettes out on me . <end>',
#  'L3489': '<start> Yeah , he hated me from day when I was born . Put it out . Can you put the cigarette out ? <end>',
#  'L3488': '<start> Your father blamed you for your mother s blindness ? <end>',
#  'L3487': '<start> Yeah , yeah . bad doctor gave her bad drugs which made her go blind . And my father blamed me for her blindness . <end>',
#  'L3486': '<start> Back in the Czech Republic ? <end>',
#  'L3485': '<start> Yeah , she went blind giving birth to me . She went to fucking black market doctor to induce me . <end>',
#  'L3484': '<start> Your mother was blind ? <end>',
#  'L3483': '<start> My father always degraded me . Killed my self esteem . And my mother was blind . <end>',
#  'L3482': '<start> Tell me about yourself . What you did as a young boy . what your parents were like . <end>',
#  'L3481': '<start> Give me another one , please . <end>',
#  'L3480': '<start> I need to know about your background . I need to know about your upbringing . Why you re here . <end>',
#  'L3479': '<start> What else do you need ? <end>',
#  'L3478': '<start> This is not about money , Emil . I need your trust in me . <end>',
#  'L3477': '<start> Thirty percent . No more . Or I call another lawyer . This is the biggest case of your life . Don t try to negotiate . Thirty percent . Say yes or no . <end>',
#  'L3476': '<start> But it s . <end>',
#  'L3475': '<start> No . No way . <end>',
#  'L3474': '<start> I would say . half . Half is fair . <end>',
#  'L3473': '<start> What s your cut ? How much ? <end>',
#  'L3472': '<start> Look , I haven t really focused on that kind of thing . <end>',
#  'L3471': '<start> What about my movie rights ? Book rights ? <end>',
#  'L3470': '<start> Don t worry about him . Think about yourself . <end>',
#  'L3469': '<start> No , he is here . Shit . <end>',
#  'L3468': '<start> Disappeared . They re looking everywhere . Maybe he went back to Czechoslovakia . <end>',
#  'L3467': '<start> What about Oleg ? <end>',
#  'L3466': '<start> Well , you didn t appreciate the severity of it until recently . No question about that . <end>',
#  'L3465': '<start> I was all of these . <end>',
#  'L3464': '<start> . delusions and paranoia . <end>',
#  'L3461': '<start> Oh , sure . <end>',
#  'L3460': '<start> You bring the cigarettes ? <end>',
#  'L3459': '<start> I brought you some letters . It s really fan mail . Women mostly . One wants to buy you clothes , another sent a check . Another wants a check . <end>',
#  'L3396': '<start> I m invoking rights this man is represented by counsel . I m coming with him . <end>',
#  'L3395': '<start> Yes . Yes , come with me ! <end>',
#  'L3394': '<start> I m coming with you . <end>',
#  'L3393': '<start> Where are we going ? <end>',
#  'L3392': '<start> Don t say anything . <end>',
#  'L3385': '<start> He has the camera ! He took the movie ! <end>',
#  'L3384': '<start> Emil . Take it easy . Stay with me . Sit down . What do you need ? What are you looking for ? <end>',
#  'L3383': '<start> Oh no ! No ! Shit ! <end>',
#  'L3382': '<start> Here . I have your money . <end>',
#  'L3381': '<start> I m not your lawyer until I see the money . <end>',
#  'L3380': '<start> Are you my attorney ? I m Emil . I m insane . <end>',
#  'L3517': '<start> Daphne , I . <end>',
#  'L3516': '<start> I don t want to drag you down with me . <end>',
#  'L3515': '<start> . Do you really want me to forget about you ? <end>',
#  'L3514': '<start> Forget about me . You have enough problems of your own . <end>',
#  'L3330': '<start> Pouring it out ! <end>',
#  'L3329': '<start> What are you doing ? <end>',
#  'L3318': '<start> I ll get my clothes . <end>',
#  'L3317': '<start> I ll make some for us . <end>',
#  'L3316': '<start> In the kitchen . <end>',
#  'L3315': '<start> Do you have coffee ? <end>',
#  ...}

# %%
question = []
answer = []
for line in lines:
    for i in range(len(line)-1):
        question.append(data[line[i]])
        answer.append(data[line[i+1]])
len(question), len(answer)
# Out:
# (221616, 221616)

# %%
import pandas as pd
pd.options.display.max_colwidth =600
# movie_df = pd.DataFrame(list(zip(question, answer)),columns=['question','answer'])
# movie_df

# %% [markdown]
# ### Wikipedia dataset preprocessing

# %%
with open("wikipedia_conversations_corpus_v1.01/wikipedia.talkpages.conversations.txt") as f:
    x = f.read().split("\n\n")
print(len(x))
x[:10]
# Out:
# 125293
# ['524288 +++$+++ Frightner +++$+++ AnonEMouse +++$+++ 524288 +++$+++ initial_post +++$+++ 2007-09-07 11:49:00 +++$+++ 1.189190940E09 +++$+++ You should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for \\"information purposes\\".  +++$+++ You should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for "information purposes". [[User:Frightner|Frightner]] 11:49, 7 September 2007 (UTC)\n524289 +++$+++ Revizionist +++$+++ AnonEMouse +++$+++ 524288 +++$+++ -1 +++$+++ 2007-09-07 15:41:00 +++$+++ 1.189204860E09 +++$+++ Yes I agree. The law permits usage of documents, photographs and other materials for educational and informational purposes. There was a normative act issued by the government of the Republic of Macedonia that even allowed citizens to make photocopies or photograph rare archive materials.  +++$+++ :::Yes I agree. The law permits usage of documents, photographs and other materials for educational and informational purposes. There was a normative act issued by the government of the Republic of Macedonia that even allowed citizens to make photocopies or photograph rare archive materials. [[User:Revizionist|Revizionist]] 15:41, 07 September 2007 (UTC)',
#  '1 +++$+++ Johannes003 +++$+++ Vensatry +++$+++ 1 +++$+++ initial_post +++$+++ 2011-07-15 08:38:00 +++$+++ 1.310744280E09 +++$+++ Yes, that\'s good. Revathy\'s page looked very reliable, that\'s why we used that as a source.  +++$+++ Yes, that\'s good. Revathy\'s page looked very reliable, that\'s why we used that as a source. [[User:Johannes003|Johannes003]] ([[User talk:Johannes003|talk]]) 08:38, 15 July 2011 (UTC)\n2 +++$+++ Johannes003 +++$+++ Vensatry +++$+++ 1 +++$+++ 1 +++$+++ 2011-07-15 09:15:00 +++$+++ 1.310746500E09 +++$+++ Nagma\'a site, at least that filmography page, looks like taken from Wikipedia itself. I didn\'t remove it from time being, but I don\'t think it\'s true.  +++$+++ : Nagma\'a site, at least that filmography page, looks like taken from Wikipedia itself. I didn\'t remove it from time being, but I don\'t think it\'s true. [[User:Johannes003|Johannes003]] ([[User talk:Johannes003|talk]]) 09:15, 15 July 2011 (UTC)\n3 +++$+++ Johannes003 +++$+++ Vensatry +++$+++ 1 +++$+++ 2 +++$+++ 2011-07-15 10:33:00 +++$+++ 1.310751180E09 +++$+++ I don\'t think there are many such official reliable sites left yet. The problem is most \\"official sites\\" are not really official, and often based on Wikipedia itself, and you don\'t know what to believe and what not. We used Madras Talkies\' page, which is dead now. [http:\\/\\/kavithalayaa.com\\/ Kavithalayaa]\'s site is there, also AVM Production\'s site might be useful perhaps, but I can\'t enter that. Generally official sites of production houses seem to be very reliable ones.  +++$+++ :: I don\'t think there are many such official reliable sites left yet. The problem is most "official sites" are not really official, and often based on Wikipedia itself, and you don\'t know what to believe and what not. We used Madras Talkies\' page, which is dead now. [http://kavithalayaa.com/ Kavithalayaa]\'s site is there, also AVM Production\'s site might be useful perhaps, but I can\'t enter that. Generally official sites of production houses seem to be very reliable ones. [[User:Johannes003|Johannes003]] ([[User talk:Johannes003|talk]]) 10:33, 15 July 2011 (UTC)\n4 +++$+++ Michael-Billa +++$+++ Vensatry +++$+++ 1 +++$+++ -1 +++$+++ 2011-07-27 03:22:00 +++$+++ 1.311762120E09 +++$+++ Most of the so called \\"official sites\\" are maintained by fans or cinema based web companies. Not sure how reliable are they. <span style=\\"color:green;font-size:small;;font-family:Segoe Print;\\">-<i>B<\\/i>iLLa-<\\/span> +++$+++ :::: Most of the so called "official sites" are maintained by fans or cinema based web companies. Not sure how reliable are they. <span style="color:green;font-size:small;;font-family:Segoe Print;">-<i>B</i>iLLa-</span>[[User talk:Michael-Billa| <span style="color:green;font-size:small;;font-family:Segoe Print;">•<sup>talk</sup>•</span>]] 03:22, 27 July 2011 (UTC)',
#  '524290 +++$+++ AnonEMouse +++$+++ AnonEMouse +++$+++ 524290 +++$+++ initial_post +++$+++ 2007-09-07 13:46:00 +++$+++ 1.189197960E09 +++$+++ You closed [[Wikipedia:Articles for deletion\\/J. Kevin Tumlinson]] after one day without mentioning anything about speedy deletion or giving reasons. Not that I\'m objecting \'\'too\'\' much, but did you realize it was only one day? -- +++$+++ You closed [[Wikipedia:Articles for deletion/J. Kevin Tumlinson]] after one day without mentioning anything about speedy deletion or giving reasons. Not that I\'m objecting \'\'too\'\' much, but did you realize it was only one day? --[[User:AnonEMouse|AnonEMouse]] <sup>[[User_talk:AnonEMouse|(squeak)]]</sup> 13:46, 7 September 2007 (UTC)\n524291 +++$+++ FayssalF +++$+++ AnonEMouse +++$+++ 524290 +++$+++ 524290 +++$+++ 2007-09-07 14:31:00 +++$+++ 1.189200660E09 +++$+++ Well, notability cannot be acquired in 4 days. That was my reasoning behind the early closure. However, if you still believe the closure was out of process, you can still refer to the deletion review. -  +++$+++ :Well, notability cannot be acquired in 4 days. That was my reasoning behind the early closure. However, if you still believe the closure was out of process, you can still refer to the deletion review. - [[User:FayssalF|<font size="2px" face="Verdana"><font color="DarkSlateBlue">FayssalF</font></font>]] - <small>[[User talk:FayssalF|<font style="background: gold"><sup>\'\'Wiki me up\'\'® </sup></font>]]</small> 14:31, 7 September 2007 (UTC)\n524292 +++$+++ AnonEMouse +++$+++ AnonEMouse +++$+++ 524290 +++$+++ 524291 +++$+++ 2007-09-07 14:32:00 +++$+++ 1.189200720E09 +++$+++ No, no, I was the nominator! Just wanted to make sure it wasn\'t done in error. -- +++$+++ :: No, no, I was the nominator! Just wanted to make sure it wasn\'t done in error. --[[User:AnonEMouse|AnonEMouse]] <sup>[[User_talk:AnonEMouse|(squeak)]]</sup> 14:32, 7 September 2007 (UTC)\n524293 +++$+++ FayssalF +++$+++ AnonEMouse +++$+++ 524290 +++$+++ 524292 +++$+++ 2007-09-07 14:36:00 +++$+++ 1.189200960E09 +++$+++ I was a bit surprised because i know you were the nominator ;) No, it wasn\'t done in error. -  +++$+++ ::: I was a bit surprised because i know you were the nominator ;) No, it wasn\'t done in error. - [[User:FayssalF|<font size="2px" face="Verdana"><font color="DarkSlateBlue">FayssalF</font></font>]] - <small>[[User talk:FayssalF|<font style="background: gold"><sup>\'\'Wiki me up\'\'® </sup></font>]]</small> 14:36, 7 September 2007 (UTC)',
#  '262147 +++$+++ Venerock +++$+++ Dana boomer +++$+++ 262147 +++$+++ initial_post +++$+++ 2010-10-03 18:54:00 +++$+++ 1.286157240E09 +++$+++ Hello Dana, thanks for contribute in this [[Template:Spanish horses|template]], but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. Enjoy your day ;)-- +++$+++ Hello Dana, thanks for contribute in this [[Template:Spanish horses|template]], but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. Enjoy your day ;)--[[User:Venerock|Venerock]] ([[User talk:Venerock|talk]]) 18:54, 3 October 2010 (UTC)\n262148 +++$+++ Dana boomer +++$+++ Dana boomer +++$+++ 262147 +++$+++ 262147 +++$+++ 2010-10-03 18:58:00 +++$+++ 1.286157480E09 +++$+++ My apologies, I forgot to include the disambiguator. Please check now - it should be right. Thanks for letting me know.  +++$+++ :My apologies, I forgot to include the disambiguator. Please check now - it should be right. Thanks for letting me know. [[User:Dana boomer|Dana boomer]] ([[User talk:Dana boomer#top|talk]]) 18:58, 3 October 2010 (UTC)',
#  "6 +++$+++ Johannes003 +++$+++ Vensatry +++$+++ 6 +++$+++ initial_post +++$+++ 2011-07-30 13:22:00 +++$+++ 1.312057320E09 +++$+++ Hey, who said so? Frankly, I have absolutely no idea, sorry!  +++$+++ Hey, who said so? Frankly, I have absolutely no idea, sorry! [[User:Johannes003|Johannes003]] ([[User talk:Johannes003|talk]]) 13:22, 30 July 2011 (UTC)\n7 +++$+++ Johannes003 +++$+++ Vensatry +++$+++ 6 +++$+++ 6 +++$+++ 2011-07-30 13:57:00 +++$+++ 1.312059420E09 +++$+++ Maybe, we should check out who added that, it could be some fanatic IP user. There will have been nominees, since there were nominees in earlier ceremonies and in the Telugu section, too, but how to find out? If there was a video coverage of that ceremony available we would know. Otherwise, I would remove it as it's unsourced.  +++$+++ : Maybe, we should check out who added that, it could be some fanatic IP user. There will have been nominees, since there were nominees in earlier ceremonies and in the Telugu section, too, but how to find out? If there was a video coverage of that ceremony available we would know. Otherwise, I would remove it as it's unsourced. [[User:Johannes003|Johannes003]] ([[User talk:Johannes003|talk]]) 13:57, 30 July 2011 (UTC)",
#  "262145 +++$+++ Kudpung +++$+++ Dana boomer +++$+++ 262145 +++$+++ initial_post +++$+++ 2010-10-03 10:32:00 +++$+++ 1.286127120E09 +++$+++ H  Dana, totally  amiss of me - belated congrats for  your promotion! I  voted for  you  without  any  hesitation. I'm  pleased to  hear from  Pike  that  you  might  be reviewing  the Finnhorse, I  can't  think  of anyone better for  the job. -- +++$+++ H  Dana, totally  amiss of me - belated congrats for  your promotion! I  voted for  you  without  any  hesitation. I'm  pleased to  hear from  Pike  that  you  might  be reviewing  the Finnhorse, I  can't  think  of anyone better for  the job. --[[User:Kudpung|Kudpung]] ([[User talk:Kudpung|talk]]) 10:32, 3 October 2010 (UTC)\n262146 +++$+++ Dana boomer +++$+++ Dana boomer +++$+++ 262145 +++$+++ 262145 +++$+++ 2010-10-03 12:15:00 +++$+++ 1.286133300E09 +++$+++ Thank you very much! I am going to try to take a look over Finnhorse - actually, I think I'll go start looking at it right now while I have a few minutes.  +++$+++ :Thank you very much! I am going to try to take a look over Finnhorse - actually, I think I'll go start looking at it right now while I have a few minutes. [[User:Dana boomer|Dana boomer]] ([[User talk:Dana boomer#top|talk]]) 12:15, 3 October 2010 (UTC)",
#  "262152 +++$+++ Rms125a@hotmail.com +++$+++ Dana boomer +++$+++ 262152 +++$+++ initial_post +++$+++ 2010-10-03 20:39:00 +++$+++ 1.286163540E09 +++$+++ Hi. Just writing that you closed out the [[WP:CFD]] as a '''merge and delete''', but category appears open still at this moment. Yours,  +++$+++ Hi. Just writing that you closed out the [[WP:CFD]] as a '''merge and delete''', but category appears open still at this moment. Yours, [[User:Rms125a@hotmail.com|Rms125a@hotmail.com]] ([[User talk:Rms125a@hotmail.com|talk]]) 20:39, 3 October 2010 (UTC)\n262153 +++$+++ Dana boomer +++$+++ Dana boomer +++$+++ 262152 +++$+++ 262152 +++$+++ 2010-10-03 20:40:00 +++$+++ 1.286163600E09 +++$+++ Yes, I know. It's on the list at [[Wikipedia:Categories_for_discussion\\/Working]], and the bot should get to it shortly.  +++$+++ :Yes, I know. It's on the list at [[Wikipedia:Categories_for_discussion/Working]], and the bot should get to it shortly. [[User:Dana boomer|Dana boomer]] ([[User talk:Dana boomer#top|talk]]) 20:40, 3 October 2010 (UTC)",
#  '9 +++$+++ Secret of success +++$+++ Vensatry +++$+++ 9 +++$+++ initial_post +++$+++ 2011-07-31 11:22:00 +++$+++ 1.312136520E09 +++$+++ Well, no website is 100% perfect, you got to understand that. Are you saying TOI is an unreliable source? Mention of Shankar as Shankar Mahadevan might have been a mistake, I\'ll contact them and ask them to correct it. What else do you want me to do?  +++$+++ Well, no website is 100% perfect, you got to understand that. Are you saying TOI is an unreliable source? Mention of Shankar as Shankar Mahadevan might have been a mistake, I\'ll contact them and ask them to correct it. What else do you want me to do? [[User:Secret of success|Secret of success]] ([[User talk:Secret of success|talk]]) 11:22, 31 July 2011 (UTC)\n10 +++$+++ Vensatry +++$+++ Vensatry +++$+++ 9 +++$+++ 9 +++$+++ 2011-07-31 11:27:00 +++$+++ 1.312136820E09 +++$+++ I don\'t care. This is not the place to elevate your favourite Star\'s films. I\'m not questioning about the credibility of TOI. There is a consensus not to add budget\\/gross figures for any Indian movie, if it\'s speculated at a higher rate. I think you might be aware of the \\"Enthiran issue\\". Even official sources were not considered. -- +++$+++ : I don\'t care. This is not the place to elevate your favourite Star\'s films. I\'m not questioning about the credibility of TOI. There is a consensus not to add budget/gross figures for any Indian movie, if it\'s speculated at a higher rate. I think you might be aware of the "Enthiran issue". Even official sources were not considered. --[[User:Vensatry|<span style="color:#556655"><small>\'\'\'Commander\'\'\'</small></span>]] <sub>[[User talk:Vensatry|<span style="color:#556655"><small>\'\'\'(Ping Me)\'\'\'</small></span>]]</sub> 11:27, 31 July 2011 (UTC)',
#  "262154 +++$+++ JCDenton2052 +++$+++ Dana boomer +++$+++ 262154 +++$+++ initial_post +++$+++ 2010-10-05 02:53:00 +++$+++ 1.286272380E09 +++$+++ Could you restore Category:Second wave synthpop acts (or at least the bands formerly listed therein) to my userspace? I was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. Thanks!  +++$+++ Could you restore Category:Second wave synthpop acts (or at least the bands formerly listed therein) to my userspace? I was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. Thanks! [[User:JCDenton2052|JCDenton2052]] ([[User talk:JCDenton2052|talk]]) 02:53, 5 October 2010 (UTC)\n262155 +++$+++ Courcelles +++$+++ Dana boomer +++$+++ 262154 +++$+++ 262154 +++$+++ 2010-10-05 02:59:00 +++$+++ 1.286272740E09 +++$+++ There would be nothing to restore, and categories can't be moved even if there were.  Category pages contain nothing, articles are added to it by an addition of code at the bottom of each article.  When a category is deleted, CFD has an Adminbot that goes through each article and removes the category.  The best you could do would be to find the edits in [[User:Cydebot]]'s contribution record, and then you'd be able to see what was in the category pre-deletion.  +++$+++ :There would be nothing to restore, and categories can't be moved even if there were.  Category pages contain nothing, articles are added to it by an addition of code at the bottom of each article.  When a category is deleted, CFD has an Adminbot that goes through each article and removes the category.  The best you could do would be to find the edits in [[User:Cydebot]]'s contribution record, and then you'd be able to see what was in the category pre-deletion. [[User:Courcelles|Courcelles]] 02:59, 5 October 2010 (UTC)\n262156 +++$+++ JCDenton2052 +++$+++ Dana boomer +++$+++ 262154 +++$+++ 262155 +++$+++ 2010-10-05 03:27:00 +++$+++ 1.286274420E09 +++$+++ Found them. Thanks for your help!  +++$+++ ::Found them. Thanks for your help! [[User:JCDenton2052|JCDenton2052]] ([[User talk:JCDenton2052|talk]]) 03:27, 5 October 2010 (UTC)",
#  '11 +++$+++ Karthikndr +++$+++ Vensatry +++$+++ 11 +++$+++ initial_post +++$+++ 2011-07-31 13:24:00 +++$+++ 1.312143840E09 +++$+++ I agree i copied, even he mi8 know it very well. I dont know 2 design and all but some thing inside, i got my own work also. If u dont mind can i copy abit of urs. Even ur page looks good!!  +++$+++ I agree i copied, even he mi8 know it very well. I dont know 2 design and all but some thing inside, i got my own work also. If u dont mind can i copy abit of urs. Even ur page looks good!! [[User:Karthikndr|Karthik Nadar]] ([[User talk:Karthikndr|talk]]) 13:24, 31 July 2011 (UTC)\n12 +++$+++ Karthikndr +++$+++ Vensatry +++$+++ 11 +++$+++ 11 +++$+++ 2011-07-31 14:01:00 +++$+++ 1.312146060E09 +++$+++ Ok! Ty for the info and links. Will create new design asap.  +++$+++ :Ok! Ty for the info and links. Will create new design asap. [[User:Karthikndr|Karthik Nadar]] ([[User talk:Karthikndr|talk]]) 14:01, 31 July 2011 (UTC)']

# %%
def create_id_to_conv_pair(convs):
    p = {}
    for lines in convs.split("\n"):
        z = lines.split(" +++$+++ ")
        p[z[0]] = z[7]
    return p

question = []
answer = []
count = 0
conv_exception = []
for convs in x:
    try:
        pairs = create_id_to_conv_pair(convs)
        for i in convs.split("\n"):
            y = i.split(" +++$+++ ")
            if (y[4] == "initial_post" ):
                pass
            elif (y[4] == '-1'):
                pass
            else:
                question.append(pairs[y[4]])
                answer.append(pairs[y[0]])
    except Exception as e:
        count+= 1
        conv_exception.append(convs)
        pass
len(question), len(answer)
# Out:
# (240252, 240252)

# %%
df = pd.DataFrame(list(zip(question, answer)), columns=['question','answer'])
df.drop_duplicates(subset='question', inplace=True)
x = df.loc[df['question'].str.len() < 200 ]
x = x.loc[df['answer'].str.len()  < 200]
len(df), len(x)
# Out:
# (193136, 53466)

# %%
x.head()
# Out:
#                                                                                                                                                                                           question  \
# 0                                                                                                     Yes, that's good. Revathy's page looked very reliable, that's why we used that as a source.
# 4                                                                                                                No, no, I was the nominator! Just wanted to make sure it wasn't done in error. --
# 8                                                         Hi. Just writing that you closed out the [[WP:CFD]] as a '''merge and delete''', but category appears open still at this moment. Yours,
# 12  I agree i copied, even he mi8 know it very well. I dont know 2 design and all but some thing inside, i got my own work also. If u dont mind can i copy abit of urs. Even ur page looks good!!
# 14   Thanks. I understand that there is a lot of controversy here, even between respected scholars. We need to document that disagreement in our articles, hopefully without attacking editors. --
#
#                                                                                                                                                      answer
# 0   Nagma'a site, at least that filmography page, looks like taken from Wikipedia itself. I didn't remove it from time being, but I don't think it's true.
# 4                                                            I was a bit surprised because i know you were the nominator ;) No, it wasn't done in error. -
# 8                                 Yes, I know. It's on the list at [[Wikipedia:Categories_for_discussion\/Working]], and the bot should get to it shortly.
# 12                                                                                             Ok! Ty for the info and links. Will create new design asap.
# 14         Capricornis, stop insinuating. And please refrain from various [[Ad hominem]] arguments, as they are falacies. Comment on contributions please.

# %% [markdown]
# ### Custome dataset Preprocessing

# %%
with open("/text/rudra/chatbot/data/data") as f:
    x = f.read().split("\n\n\n")
x
# Out:
# ['Person A: "Hi, my name is Steve. It\'s nice to meet you."\nPerson B: "I\'m Jack. It\'s a pleasure to meet you, Steve."\nPerson A: "What do you do for a living Jack?"\nPerson B: "I work at the bank."',
#  'Person A: "What is your name?"\nPerson B: "Jackson."\nPerson A: "What was that again?"',
#  'Person A: "Hey John, how have you been?"\nPerson B: "What a surprise. I haven\'t seen you in a long time. How have you been?"\nPerson A: "I\'m doing very well. How about you?"\nPerson B: "I finally have some free time. I just finished taking a big examination, and I\'m so relieved that I\'m done with it."',
#  'Person A: "Hi Nancy, what have you been up to?"\nPerson B: "The same ole same ole." \nPerson A: "I\'m pretty busy at work these days, but otherwise, everything is great."',
#  'Person A: "Andy, it\'s been a long time, how are you man?"\nPerson B: "What a surprise. I haven\'t seen you in a long time. How have you been?"\nPerson A: "Do you come to this restaurant often?"\nPerson B: "I\'ve been here a couple of times, but I don\'t come on a regular basis."',
#  'A: "Hi, how are you doing?"\nB: "I\'m doing great. How about you?"\nA: "Not too bad."\nB: "Do you come to this restaurant often?"\nA: "I\'ve been here a couple of times, but I don\'t come on a regular basis. What have you been up to?"\nB: "I\'m pretty busy at work these days, but otherwise, everything is great."\nA: "Well, have a good evening."\nB: "You too."',
#  'A: "It\'s nice to meet you. My name is Jack."\nB: "I\'m Steve. It\'s a pleasure to meet you."\nA: "What was your name again?"\nB: "Steve."\nA: "So Steve, What do you do for a living?"\nB: "I work at the public library. How about you?"\nA: "I\'m a University student."\nB: "That\'s great. It was nice meeting you."\nA: "Yeah. It was a pleasure meeting you."',
#  'A: "Hey Jack, it\'s good to see you."\nB: "Wow. How long has it been? It seems like more than a year. I\'m doing pretty well. How about you?"\nA: "Not too bad."\nB: "What movie did you come to see?"\nA: "I came here to see Matrix Revolution. How about you?"\nB: "I\'m going to watch Finding Nemo."',
#  'A: "Hey there. What have you been up to?"\nB: "Nothing really."\nA: "How about your work?"\nB: "It\'s so boring there. I really wish I had a different job."\nA: "Is it really that bad?"\nB: "Yeah. Most of the time, I have nothing to do. But whenever I have something to do, it\'s boring work because it is the same old thing."\nA: "Why don\'t you find a different job then?"\nB: "Maybe I should."',
#  'A: "Hi Steve, what\'s your plan for tonight?"\nB: "I don\'t have any plans. Are you doing anything special?"\nA: "Well, if you\'re bored, let\'s plan on meeting up tonight."\nB: "That sounds like a good idea. Should we invite Bob?"\nA: "He\'s a little boring."\nB: "What do you mean?"\nA: "Well, he doesn\'t drink, play video games, pool, or really anything. The only thing he talks about is history."\nB: "You do have a point. We\'ll leave him out tonight."\nA: "Alright. Let\'s meet in front of the university bookstore."\nB: "Perfect. I\'ll see you later tonight."',
#  'A: "What are you doing now?"\nB: "I\'m watching TV."\nA: "What are you watching?"\nB: "I\'m watching Friends. What are you doing?"\nA: "I\'m doing my homework, but I really need to take a break."\nB: "You want to do something?"\nA: "Yes. But I shouldn\'t. I got to finish my assignment now."\nB: "Alright. Call me later then."\nA: "OK. Bye."',
#  'A: "Where are you going now?"\nB: "I\'m going to the bank."\nA: "Aren\'t you supposed to be at work?"\nB: "I\'m working now. I\'m making a deposit for our company."\nA: "Where do you work?"\nB: "I work for a restaurant as a controller."\nA: "Wow. That\'s great."\nB: "Great seeing you. I have to go now. I\'ll talk to you later."',
#  'A: "Hi Steve. What are you doing here?"\nB: "I\'m meeting a friend here for dinner. How about you?"\nA: "I\'m on my way home but I needed to stop by the book store to buy a text book."\nB: "Didn\'t you finish school yet?"\nA: "I have one more year, and then I\'m done."\nB: "What are you majoring in?"\nA: "I\'m majoring in Sociology"\nB: "How do you like your major?"\nA: "I really find the subject very interesting. I\'m enjoying all my classes."\nB: "That\'s great."\nA: "I\'d better go now. I don\'t want to miss the bus."\nB: "Alright, I\'ll talk to you later."\nA: "Okay. See you later."',
#  'Person A: "Bob is in the hospital, did you get a chance to visit him?"\nPerson B: "I\'m going to see Bob tomorrow."\nPerson A: "I thought you had to meet John tomorrow?"\nPerson B: "I\'m going to meet John at the airport at 6 O\'clock tonight."',
#  'Person A: "I\'m going home now, do you want to head out together?"\nPerson B: "No Thanks. I\'m going to go home in about an hour."\nPerson A: "Didn\'t you need to buy a present for your brother\'s birthday?"\nPerson B: "I\'m going to do that tomorrow."',
#  'Person A: "I\'m going to go to the bus stop right after class, so I won\'t have time to meet you."\nPerson B: "That\'s OK. We can always get together tomorrow."',
#  'Person A: "Why do you look so stressed?"\nPerson B: "I\'m going to be dead if I don\'t finish this project by tomorrow."\nPerson A: "I thought you had 2 weeks to finish this project."\nPerson B: "I don\'t have time to explain now. I\'ll talk to you later."',
#  'Person A: "Since we are done with school, when are you going back home?"\nPerson B: "I\'m going to go home next week."\nPerson A: "Me too. Do you want to meet at the train station on Sunday?"\nPerson B: "Sure. I\'ll meet you there at five."',
#  'A: "Do you have any plans tonight?"\nB: "I have class until 5 O\'clock, but I\'m free after that."\nA: "Do you want to grab dinner?"\nB: "I don\'t have any dinner plans so that sounds great."\nA: "What time should we meet?"\nB: "I need to go to the book store first, so let\'s meet at 6 O\'clock."',
#  'A: "Let\'s go to Everland next week"\nB: "I can\'t. I\'m way too busy."\nA: "What are you doing next week?"\nB: "On Monday, I\'m going to meet my professor. Tuesday, I have a job interview. Wednesday, I\'m going to the dentist. And on Thursday, I have to go visit my parents."\nA: "Why are you so busy?"\nB: "I\'ve been procrastinating for a long time."',
#  'A: "What are you doing over the weekend?"\nB: "I\'m going to exercise, meet some friends, and then watch tv."\nA: "Who are you going to meet?"\nB: "My friend from middle school is visiting, so we are going to have dinner on Saturday."\nA: "How long is he going to stay?"\nB: "He is only here for a day."\nA: "Where are you going to eat dinner?"\nB: "I plan on taking him to an Italian restaurant."',
#  'Person A: "Why didn\'t you come to my party last night?"\nPerson B: "I\'m sorry I couldn\'t make it. I had to go visit my grandmother at the hospital."\nPerson A: "Oh, I\'m sorry to hear that. Is she doing ok?"\nPerson B: "They just completed a small operation and the doctors said she should recover."',
#  'Person A: "Did you get a chance to go to that new restaurant down the street?"\nPerson B: "Yeah. I ordered the special, but the server screwed up my order."\nPerson A: "That sucks. So what ended up happening?"\nPerson B: "They finally got my steak out, but it was overcooked. It was a terrible experience."',
#  'Person A: "What did you do last weekend?"\nPerson B: "I went on a date with Sammy."\nPerson A: "Really? How was it?"\nPerson B: "I couldn\'t ask for a better night. We talked all throughout our two hour dinner, and then we sat by the river and cuddled in the night."',
#  'Person A: "Didn\'t you finish finals week?"\nPerson B: "Don\'t remind me. I think I failed most of the exams."\nPerson A: "Why did you do so terrible?"\nPerson B: "My mind just went blank. I think I overloaded my brain. I just couldn\'t concentrate during the exams."',
#  'Person A: "What is the average temperature in Seoul during June?"\nPerson B: "It is usually about 26 degrees Celsius during June."\nPerson A: "What is that in Fahrenheit?"\nPerson B: "That would be about 80 degrees Fahrenheit."',
#  'Question: "What is the weather like in Korea?"\nAnswer: "Well, the weather in Korea is unique with four distinct seasons. In the winter, the temperature is about zero degrees Celsius. But, because it doesn\'t rain much in the winter, there isn\'t much snow and the air is very dry. In spring, the days warm up significantly but the night gets a little chilly. The summer has two characteristics. It is very hot and humid most of the time, and for about 3 weeks or so, we have a rainy season called monsoon. It gets very rainy and windy during that time period. But we all look forward to autumn. It is a beautiful time of year and the temperature is very pleasant. If you plan on visiting Korea, I highly recommend visiting during autumn."\n\nQuestion: "Which season do you like the most?"\nAnswer: "I like summer the most, but at the same time, I hate it. I like summer because it\'s warm. I don\'t mind the heat and I like the longer days. So, I can do more activities like swimming, bicycling, rollerblading, and many other outdoor activities. I usually take a short vacation during the summer so I always look forward to that. However, the part about summer I hate the most is during the monsoon season. I can tolerate the humidity, but when it gets hot and humid along with the rain and the wind, then it gets terrible."',
#  'A: "Hey John, it\'s beautiful out today, isn\'t it?"\nB: "Yeah. I wish it would be like this everyday."\nA: "Did you see the weather forecast?"\nB: "Unfortunately, it\'s supposed to start raining tomorrow night."',
#  'A: "Do you know what the weather is going to be like tomorrow?"\nB: "It\'s supposed to be the same as today. I don\'t think the weather will change much for the next week or so."\nA: "That\'s great."\nB: "Why are you so happy? Do you have anything planned?"\nA: "Yeah, I\'m going to Everland with my family this weekend so I was hoping for good weather."',
#  'A: "I can\'t believe it is raining so much."\nB: "It\'s not that bad. Last year we had floods in 4 different areas of the city."\nA: "Really? Does it always rain so much during this time of year?"\nB: "This is not as bad as usual. During the monsoon season, we usually have rain for 3 weeks."',
#  'One: "Hi Mary."\nTwo: "Oh, hi."\nOne: "How are you doing?"\nTwo: "I\'m doing alright. How about you?"\nOne: "Not too bad. The weather is great isn\'t it?"\nTwo: "Yes. It\'s absolutely beautiful today."\nOne: "I wish it was like this more frequently."\nTwo: "Me too."\nOne: "So where are you going now?"\nTwo: "I\'m going to meet a friend of mine at the department store."\nOne: "Going to do a little shopping?"\nTwo: "Yeah, I have to buy some presents for my parents."\nOne: "What\'s the occasion?"\nTwo: "It\'s their anniversary."\nOne: "That\'s great. Well, you better get going. You don\'t want to be late."\nTwo: "I\'ll see you next time."\nOne: "Sure. Bye."',
#  'Them: "Hi. My name is Josh. It\'s a pleasure to meet you."\nYou: "Hi Josh. I\'m glad to be here."\nThem: "Did you have any problems finding this place."\nYou: "I didn\'t have any problems. I found directions on the internet so it was pretty easy to find. However, the traffic was not that great."\nThem: "Traffic is never good around here."\nYou: "I agree. It would be great if there was a train or a subway line that went through here."\nThem: "That would be so great. I would definitely take the train if they had it."\nYou: "Trains are great because you can read a book or get a little rest instead of having to fight the traffic."\nThem: "Very true. Well, let me begin by telling you about our company..."',
#  'Person A: "Hey John, I\'m going to see The Matrix with Peter and Brad. Do you wanna come?"\nPerson B: "When are you guys going?"\nPerson A: "We\'re going to see the eight O\'clock showing."\nPerson B: "That would be great. Where are you guys meeting?"\nPerson A: "We\'re meeting at the theater at seven thirty."\nPerson B: "Great. I\'ll meet you guys there."',
#  'Person A: "Hey Jill."\nPerson B: "What\'s up Mike?"\nPerson A: "I was wondering if you have any plans for tomorrow night."\nPerson B: "Umm... I don\'t think I have anything special for tomorrow. Why?"\nPerson A: "Do you want to see The Titanic with me?"\nPerson B: "I wanted to see that. Yeah. Let\'s go."\nPerson A: "What time is good for you?"\nPerson B: "How about seven thirty."\nPerson A: "Sure. I\'ll meet you at the theater at seven.',
#  'A: "What type of movies do you like?"\nB: "I like comedies. How about you?"\nA: "I like action."\nB: "Action is fun too."',
#  'A: "What type of movies do you like?"\nB: "I like all sorts of movies, primarily drama and science fiction."\nA: "That\'s an interesting combination. How about western movies?"\nB: "Western and horror are the two types of movies I don\'t care for."\nA: "Why don\'t you like horror? They\'re entertaining."\nB: "Some are entertaining, but I find most of them stupid and childish. For example, I don\'t understand why a person always goes into the house alone when something is suspicious."\nA: "Ha ha. I know what you mean. But it\'s just a movie. They need for the characters to do that."',
#  'A: "Hey, you wanna see a movie tomorrow?"\nB: "Sounds like a good plan. What do you want to see?"\nA: "How about Legally Blonde."\nB: "Ah, my girlfriend wanted to see that movie. I have to take her later so I don\'t want to watch it ahead of time. How about The Cube?"\nA: "Isn\'t that a scary movie?"\nB: "How scary can it be? Come on, it\'ll be fun."\nA: "Ok. I\'ll give it a try."\nB: "That\'s the spirit. I\'ll see you tomorrow after class."\nA: "Ok. See you tomorrow."',
#  'A: "Did you like the movie?"\nB: "It was better than I thought."\nA: "The movie didn\'t have many cheesy or stupid scenes."\nB: "Yeah. I\'m glad that they didn\'t have any love scenes. Sometimes a love scene destroys a good movie."\nB: "I agree. They didn\'t need that scene."\nA: "I don\'t see the harm in that scene. They didn\'t do anything or show anything. What\'s the big deal?"\nA: "That\'s true."\nB: "But besides those one or two scenes, the movie was great."\nA: "I liked everything about it. I really liked the samurai that was beating up Cruise in the beginning of the movie. The guy second in command. He was cool too."\nB: "Every movie has a guy like him. They try to make him awesome even though they don\'t say much."\nA: "It was clear in the movie that he loved the place and the samurais. Clearly everyone knows that he isn\'t a traitor. I would have done the same thing in his position."\nB: "I think so too."\nA: "Well, all the samurais were looking for a death in battle. Cruise wasn\'t."\nA: "True."\nB: "What are we going to order?"\nA: "Me too."\nB: "I\'m just having a soup and salad."',
#  'A: "Hey Joanne. What are you up to?"\nB: "I\'m just watching some television."\nA: "I\'m so bored. I don\'t know what I\'m going to do today and it is only ten in the morning."\nB: "Me too. Do you think we are boring people?"\nA: "I don\'t think we are boring. It\'s just that we don\'t have any hobbies."\nB: "That\'s right. What do you think we should do as a hobby?"\nA: "That all depends on what you like to do. For example, I like to doodle on the notepad, so I\'m thinking about doing some real drawings."\nB: "I like to play the piano for fun."\nA: "Yeah. That can be a good hobby."\nB: "Hobbies are great. I\'m going to make a list of all the things I like to do."\nA: "That\'s a great idea. I\'m going to do the same."',
#  'A: "What do you do besides work and watching TV?"\nB: "When I have some time, I like to exercise."\nA: "Do you go jogging or do you go to a health club?"\nB: "I joined Samsung Health Club a couple of months ago."\nA: "How do you exercise?"\nB: "I usually spend 30 minutes on the bicycle for the cardio, and then I lift weights for about 45 minutes."\nA: "How often do you go?"\nB: "I want to go four times a week, but I\'m too lazy. Last week, I only went to workout once."',
#  'A: "Hey Jimmy. Let\'s go workout later today."\nB: "Sure. What time do you want to go?"\nA: "How about at 3:30."\nB: "That sounds good. Today we work on Legs and forearm."\nA: "Hey. I just played basketball earlier, so my legs are a little sore. Let\'s work out on arms and stomach today."\nB: "I\'m on a weekly schedule. You\'re messing everything up."\nA: "C\'mon. We\'re only switching two days. You can do legs on Friday."\nB: "Alright. I\'ll meet you at the gym at 3:30 then."',
#  'A: "Damn Scott. You got big."\nB: "Yeah, I\'ve been working out a lot."\nA: "How long have you been lifting weights?"\nB: "For a year and a half."\nA: "Yeah. Last time I saw you, it was like 2 years ago."\nB: "Has it been that long?"\nA: "How often do you go to the gym?"\nB: "I usually go every other day for about 3 hours."\nA: "That\'s a lot."\nB: "Yeah, I used to work out for an hour a day 4 times a week, and I saw no results. This is what you have to do to get noticeable results."\nA: "I don\'t think I have the discipline for that."\nB: "Just think of it as a hobby. Then it\'s actually fun."',
#  'A: "How are you doing?"\nB: "I\'m doing great."\nA: "What movies have you seen lately?"\nB: "I saw Forrest Gump the other day."\nA: "What type of movie is that?"\nB: "The movie type is drama."\nA: "I can\'t believe you are watching movies. The weather is great. You should be outside."\nB: "I hate the hot weather. I\'d rather stay indoors with the air conditioner."\nA: "What else do you like to do besides watching movies?"\nB: "I like to play computer games, read books, go shopping, and play pool."\nA: "Out of those what is your favorite?"\nB: "My favorite is to play computer games."\nA: "What is your favorite computer game?"\nB: "My favorite is Diablo. It used to be Star Craft, but it is getting a little old."\nA: "If you like to play so much, when do you ever exercise?"\nB: "Although I hate to exercise, I go jogging at least twice a week."\nA: "That\'s pretty good. By the way, what are you doing next Saturday?"\nB: "I am going to go to the bookstore."\nA: "I am having a party Saturday night at my house. If you have time, you should come."\nB: "That sounds like fun."\nA: "Great. I\'ll see you on Saturday."\nB: "Ok. See you later."',
#  'A: "Hello?"\nB: "Hi Steve. This is Mike. What are you doing?"\nA: "Oh, hi. I was just watching TV."\nB: "There\'s nothing to watch right now."\nA: "I know. I was watching a re-run. I have nothing to do and I was bored."\nB: "Me too. Let\'s get together and do something."\nA: "I\'d like to, but I have to meet my parents in an hour for dinner. How about tomorrow?"\nB: "Yeah. Let\'s plan something tomorrow."\nA: "Did you hear the weather forecast for tomorrow?"\nB: "I think it is going to be the same as today. Clear and sunny."\nA: "That\'s great. We can do something outdoors then."\nB: "Are there any special events going on tomorrow?"\nA: "Yeah. I think there\'s a live outdoor concert by the river tomorrow."\nB: "Oh yeah. I heard about that too. Let\'s go check it out."\nA: "Do you know what time it starts?"\nB: "It starts at one PM."\nA: "Let\'s meet for lunch at eleven thirty and afterwards, we can head over there."\nB: "Perfect. I\'ll see you in front of the apartment at eleven thirty."',
#  'A: "Steve. Is that you?"\nB: "Yeah. What\'s going on?"\nA: "Not much. What a surprise to see you here."\nB: "Yeah. It\'s been a couple of months since I saw you."\nA: "What have you been up to?"\nB: "I just started working out."\nA: "Really? Where do you work out at?"\nB: "I joined the Samsung Health Club last month."\nA: "What do you mostly do during your workout?"\nB: "I concentrate mostly on my legs, chest, arms and stomach."\nA: "I should start exercising more."\nB: "It\'s hard work while exercising, but it is a great feeling when I get done."\nA: "I have a running machine at home. I used to use it, but I already got sick of it."\nB: "Exercising at home is hard. The environment is not suited for exercising."\nA: "If I want to exercise, I will need to join a gym."\nB: "I have a couple of guest passes. You want to check out my health club."\nA: "That\'s a good idea. Let\'s go over the weekend."\nB: "Great. I\'ll call you Saturday morning."\nA: "Alright. I\'ll talk to you later."\nB: "Ok. Bye."',
#  'A: "The weather is terrible."\nB: "Yeah. It\'s been raining a lot these days."\nA: "I have been watching a lot of videos at home because of the constant rain."\nB: "Have you heard when it\'s supposed to get better?"\nA: "I saw the weather report, and it\'s going to rain for the next eight days."\nB: "That sucks so much. What are we going to do?"\nA: "I\'m getting pretty bored. We should do something despite the rain."\nB: "I\'m with you. What do you have in mind?"\nA: "I haven\'t been to the Mall in a long time. Let\'s go there."\nB: "That sounds good. They have a movie theater there, so if we get bored, we can watch a movie."\nA: "Great. I\'ll stop by your place now."\nB: "Ok. Don\'t forget to bring your umbrella. The rain can start up again anytime."\n']

# %%
x[1].split("\n")[0].replace('"','')
# Out:
# 'Person A: What is your name?'

# %%
question = []
answer =[]
for conv in x:
    for _ in range(len(conv.split("\n"))-1):
        y = conv.split("\n")
        question.append(y[_].replace('"','').split(":")[-1].strip())
        answer.append(y[_+1].replace('"','').split(":")[-1].strip())
len(question), len(answer)
# Out:
# (309, 309)

# %%
question
# Out:
# ["Hi, my name is Steve. It's nice to meet you.",
#  "I'm Jack. It's a pleasure to meet you, Steve.",
#  'What do you do for a living Jack?',
#  'What is your name?',
#  'Jackson.',
#  'Hey John, how have you been?',
#  "What a surprise. I haven't seen you in a long time. How have you been?",
#  "I'm doing very well. How about you?",
#  'Hi Nancy, what have you been up to?',
#  'The same ole same ole.',
#  "Andy, it's been a long time, how are you man?",
#  "What a surprise. I haven't seen you in a long time. How have you been?",
#  'Do you come to this restaurant often?',
#  'Hi, how are you doing?',
#  "I'm doing great. How about you?",
#  'Not too bad.',
#  'Do you come to this restaurant often?',
#  "I've been here a couple of times, but I don't come on a regular basis. What have you been up to?",
#  "I'm pretty busy at work these days, but otherwise, everything is great.",
#  'Well, have a good evening.',
#  "It's nice to meet you. My name is Jack.",
#  "I'm Steve. It's a pleasure to meet you.",
#  'What was your name again?',
#  'Steve.',
#  'So Steve, What do you do for a living?',
#  'I work at the public library. How about you?',
#  "I'm a University student.",
#  "That's great. It was nice meeting you.",
#  "Hey Jack, it's good to see you.",
#  "Wow. How long has it been? It seems like more than a year. I'm doing pretty well. How about you?",
#  'Not too bad.',
#  'What movie did you come to see?',
#  'I came here to see Matrix Revolution. How about you?',
#  'Hey there. What have you been up to?',
#  'Nothing really.',
#  'How about your work?',
#  "It's so boring there. I really wish I had a different job.",
#  'Is it really that bad?',
#  "Yeah. Most of the time, I have nothing to do. But whenever I have something to do, it's boring work because it is the same old thing.",
#  "Why don't you find a different job then?",
#  "Hi Steve, what's your plan for tonight?",
#  "I don't have any plans. Are you doing anything special?",
#  "Well, if you're bored, let's plan on meeting up tonight.",
#  'That sounds like a good idea. Should we invite Bob?',
#  "He's a little boring.",
#  'What do you mean?',
#  "Well, he doesn't drink, play video games, pool, or really anything. The only thing he talks about is history.",
#  "You do have a point. We'll leave him out tonight.",
#  "Alright. Let's meet in front of the university bookstore.",
#  'What are you doing now?',
#  "I'm watching TV.",
#  'What are you watching?',
#  "I'm watching Friends. What are you doing?",
#  "I'm doing my homework, but I really need to take a break.",
#  'You want to do something?',
#  "Yes. But I shouldn't. I got to finish my assignment now.",
#  'Alright. Call me later then.',
#  'Where are you going now?',
#  "I'm going to the bank.",
#  "Aren't you supposed to be at work?",
#  "I'm working now. I'm making a deposit for our company.",
#  'Where do you work?',
#  'I work for a restaurant as a controller.',
#  "Wow. That's great.",
#  'Hi Steve. What are you doing here?',
#  "I'm meeting a friend here for dinner. How about you?",
#  "I'm on my way home but I needed to stop by the book store to buy a text book.",
#  "Didn't you finish school yet?",
#  "I have one more year, and then I'm done.",
#  'What are you majoring in?',
#  "I'm majoring in Sociology",
#  'How do you like your major?',
#  "I really find the subject very interesting. I'm enjoying all my classes.",
#  "That's great.",
#  "I'd better go now. I don't want to miss the bus.",
#  "Alright, I'll talk to you later.",
#  'Bob is in the hospital, did you get a chance to visit him?',
#  "I'm going to see Bob tomorrow.",
#  'I thought you had to meet John tomorrow?',
#  "I'm going home now, do you want to head out together?",
#  "No Thanks. I'm going to go home in about an hour.",
#  "Didn't you need to buy a present for your brother's birthday?",
#  "I'm going to go to the bus stop right after class, so I won't have time to meet you.",
#  'Why do you look so stressed?',
#  "I'm going to be dead if I don't finish this project by tomorrow.",
#  'I thought you had 2 weeks to finish this project.',
#  'Since we are done with school, when are you going back home?',
#  "I'm going to go home next week.",
#  'Me too. Do you want to meet at the train station on Sunday?',
#  'Do you have any plans tonight?',
#  "I have class until 5 O'clock, but I'm free after that.",
#  'Do you want to grab dinner?',
#  "I don't have any dinner plans so that sounds great.",
#  'What time should we meet?',
#  "Let's go to Everland next week",
#  "I can't. I'm way too busy.",
#  'What are you doing next week?',
#  "On Monday, I'm going to meet my professor. Tuesday, I have a job interview. Wednesday, I'm going to the dentist. And on Thursday, I have to go visit my parents.",
#  'Why are you so busy?',
#  'What are you doing over the weekend?',
#  "I'm going to exercise, meet some friends, and then watch tv.",
#  'Who are you going to meet?',
#  'My friend from middle school is visiting, so we are going to have dinner on Saturday.',
#  'How long is he going to stay?',
#  'He is only here for a day.',
#  'Where are you going to eat dinner?',
#  "Why didn't you come to my party last night?",
#  "I'm sorry I couldn't make it. I had to go visit my grandmother at the hospital.",
#  "Oh, I'm sorry to hear that. Is she doing ok?",
#  'Did you get a chance to go to that new restaurant down the street?',
#  'Yeah. I ordered the special, but the server screwed up my order.',
#  'That sucks. So what ended up happening?',
#  'What did you do last weekend?',
#  'I went on a date with Sammy.',
#  'Really? How was it?',
#  "Didn't you finish finals week?",
#  "Don't remind me. I think I failed most of the exams.",
#  'Why did you do so terrible?',
#  'What is the average temperature in Seoul during June?',
#  'It is usually about 26 degrees Celsius during June.',
#  'What is that in Fahrenheit?',
#  'What is the weather like in Korea?',
#  "Well, the weather in Korea is unique with four distinct seasons. In the winter, the temperature is about zero degrees Celsius. But, because it doesn't rain much in the winter, there isn't much snow and the air is very dry. In spring, the days warm up significantly but the night gets a little chilly. The summer has two characteristics. It is very hot and humid most of the time, and for about 3 weeks or so, we have a rainy season called monsoon. It gets very rainy and windy during that time period. But we all look forward to autumn. It is a beautiful time of year and the temperature is very pleasant. If you plan on visiting Korea, I highly recommend visiting during autumn.",
#  '',
#  'Which season do you like the most?',
#  "Hey John, it's beautiful out today, isn't it?",
#  'Yeah. I wish it would be like this everyday.',
#  'Did you see the weather forecast?',
#  'Do you know what the weather is going to be like tomorrow?',
#  "It's supposed to be the same as today. I don't think the weather will change much for the next week or so.",
#  "That's great.",
#  'Why are you so happy? Do you have anything planned?',
#  "I can't believe it is raining so much.",
#  "It's not that bad. Last year we had floods in 4 different areas of the city.",
#  'Really? Does it always rain so much during this time of year?',
#  'Hi Mary.',
#  'Oh, hi.',
#  'How are you doing?',
#  "I'm doing alright. How about you?",
#  "Not too bad. The weather is great isn't it?",
#  "Yes. It's absolutely beautiful today.",
#  'I wish it was like this more frequently.',
#  'Me too.',
#  'So where are you going now?',
#  "I'm going to meet a friend of mine at the department store.",
#  'Going to do a little shopping?',
#  'Yeah, I have to buy some presents for my parents.',
#  "What's the occasion?",
#  "It's their anniversary.",
#  "That's great. Well, you better get going. You don't want to be late.",
#  "I'll see you next time.",
#  "Hi. My name is Josh. It's a pleasure to meet you.",
#  "Hi Josh. I'm glad to be here.",
#  'Did you have any problems finding this place.',
#  "I didn't have any problems. I found directions on the internet so it was pretty easy to find. However, the traffic was not that great.",
#  'Traffic is never good around here.',
#  'I agree. It would be great if there was a train or a subway line that went through here.',
#  'That would be so great. I would definitely take the train if they had it.',
#  'Trains are great because you can read a book or get a little rest instead of having to fight the traffic.',
#  "Hey John, I'm going to see The Matrix with Peter and Brad. Do you wanna come?",
#  'When are you guys going?',
#  "We're going to see the eight O'clock showing.",
#  'That would be great. Where are you guys meeting?',
#  "We're meeting at the theater at seven thirty.",
#  'Hey Jill.',
#  "What's up Mike?",
#  'I was wondering if you have any plans for tomorrow night.',
#  "Umm... I don't think I have anything special for tomorrow. Why?",
#  'Do you want to see The Titanic with me?',
#  "I wanted to see that. Yeah. Let's go.",
#  'What time is good for you?',
#  'How about seven thirty.',
#  'What type of movies do you like?',
#  'I like comedies. How about you?',
#  'I like action.',
#  'What type of movies do you like?',
#  'I like all sorts of movies, primarily drama and science fiction.',
#  "That's an interesting combination. How about western movies?",
#  "Western and horror are the two types of movies I don't care for.",
#  "Why don't you like horror? They're entertaining.",
#  "Some are entertaining, but I find most of them stupid and childish. For example, I don't understand why a person always goes into the house alone when something is suspicious.",
#  'Hey, you wanna see a movie tomorrow?',
#  'Sounds like a good plan. What do you want to see?',
#  'How about Legally Blonde.',
#  "Ah, my girlfriend wanted to see that movie. I have to take her later so I don't want to watch it ahead of time. How about The Cube?",
#  "Isn't that a scary movie?",
#  "How scary can it be? Come on, it'll be fun.",
#  "Ok. I'll give it a try.",
#  "That's the spirit. I'll see you tomorrow after class.",
#  'Did you like the movie?',
#  'It was better than I thought.',
#  "The movie didn't have many cheesy or stupid scenes.",
#  "Yeah. I'm glad that they didn't have any love scenes. Sometimes a love scene destroys a good movie.",
#  "I agree. They didn't need that scene.",
#  "I don't see the harm in that scene. They didn't do anything or show anything. What's the big deal?",
#  "That's true.",
#  'But besides those one or two scenes, the movie was great.',
#  'I liked everything about it. I really liked the samurai that was beating up Cruise in the beginning of the movie. The guy second in command. He was cool too.',
#  "Every movie has a guy like him. They try to make him awesome even though they don't say much.",
#  "It was clear in the movie that he loved the place and the samurais. Clearly everyone knows that he isn't a traitor. I would have done the same thing in his position.",
#  'I think so too.',
#  "Well, all the samurais were looking for a death in battle. Cruise wasn't.",
#  'True.',
#  'What are we going to order?',
#  'Me too.',
#  'Hey Joanne. What are you up to?',
#  "I'm just watching some television.",
#  "I'm so bored. I don't know what I'm going to do today and it is only ten in the morning.",
#  'Me too. Do you think we are boring people?',
#  "I don't think we are boring. It's just that we don't have any hobbies.",
#  "That's right. What do you think we should do as a hobby?",
#  "That all depends on what you like to do. For example, I like to doodle on the notepad, so I'm thinking about doing some real drawings.",
#  'I like to play the piano for fun.',
#  'Yeah. That can be a good hobby.',
#  "Hobbies are great. I'm going to make a list of all the things I like to do.",
#  'What do you do besides work and watching TV?',
#  'When I have some time, I like to exercise.',
#  'Do you go jogging or do you go to a health club?',
#  'I joined Samsung Health Club a couple of months ago.',
#  'How do you exercise?',
#  'I usually spend 30 minutes on the bicycle for the cardio, and then I lift weights for about 45 minutes.',
#  'How often do you go?',
#  "Hey Jimmy. Let's go workout later today.",
#  'Sure. What time do you want to go?',
#  '30.',
#  'That sounds good. Today we work on Legs and forearm.',
#  "Hey. I just played basketball earlier, so my legs are a little sore. Let's work out on arms and stomach today.",
#  "I'm on a weekly schedule. You're messing everything up.",
#  "C'mon. We're only switching two days. You can do legs on Friday.",
#  'Damn Scott. You got big.',
#  "Yeah, I've been working out a lot.",
#  'How long have you been lifting weights?',
#  'For a year and a half.',
#  'Yeah. Last time I saw you, it was like 2 years ago.',
#  'Has it been that long?',
#  'How often do you go to the gym?',
#  'I usually go every other day for about 3 hours.',
#  "That's a lot.",
#  'Yeah, I used to work out for an hour a day 4 times a week, and I saw no results. This is what you have to do to get noticeable results.',
#  "I don't think I have the discipline for that.",
#  'How are you doing?',
#  "I'm doing great.",
#  'What movies have you seen lately?',
#  'I saw Forrest Gump the other day.',
#  'What type of movie is that?',
#  'The movie type is drama.',
#  "I can't believe you are watching movies. The weather is great. You should be outside.",
#  "I hate the hot weather. I'd rather stay indoors with the air conditioner.",
#  'What else do you like to do besides watching movies?',
#  'I like to play computer games, read books, go shopping, and play pool.',
#  'Out of those what is your favorite?',
#  'My favorite is to play computer games.',
#  'What is your favorite computer game?',
#  'My favorite is Diablo. It used to be Star Craft, but it is getting a little old.',
#  'If you like to play so much, when do you ever exercise?',
#  'Although I hate to exercise, I go jogging at least twice a week.',
#  "That's pretty good. By the way, what are you doing next Saturday?",
#  'I am going to go to the bookstore.',
#  'I am having a party Saturday night at my house. If you have time, you should come.',
#  'That sounds like fun.',
#  "Great. I'll see you on Saturday.",
#  'Hello?',
#  'Hi Steve. This is Mike. What are you doing?',
#  'Oh, hi. I was just watching TV.',
#  "There's nothing to watch right now.",
#  'I know. I was watching a re-run. I have nothing to do and I was bored.',
#  "Me too. Let's get together and do something.",
#  "I'd like to, but I have to meet my parents in an hour for dinner. How about tomorrow?",
#  "Yeah. Let's plan something tomorrow.",
#  'Did you hear the weather forecast for tomorrow?',
#  'I think it is going to be the same as today. Clear and sunny.',
#  "That's great. We can do something outdoors then.",
#  'Are there any special events going on tomorrow?',
#  "Yeah. I think there's a live outdoor concert by the river tomorrow.",
#  "Oh yeah. I heard about that too. Let's go check it out.",
#  'Do you know what time it starts?',
#  'It starts at one PM.',
#  "Let's meet for lunch at eleven thirty and afterwards, we can head over there.",
#  'Steve. Is that you?',
#  "Yeah. What's going on?",
#  'Not much. What a surprise to see you here.',
#  "Yeah. It's been a couple of months since I saw you.",
#  'What have you been up to?',
#  'I just started working out.',
#  'Really? Where do you work out at?',
#  'I joined the Samsung Health Club last month.',
#  'What do you mostly do during your workout?',
#  'I concentrate mostly on my legs, chest, arms and stomach.',
#  'I should start exercising more.',
#  "It's hard work while exercising, but it is a great feeling when I get done.",
#  'I have a running machine at home. I used to use it, but I already got sick of it.',
#  'Exercising at home is hard. The environment is not suited for exercising.',
#  'If I want to exercise, I will need to join a gym.',
#  'I have a couple of guest passes. You want to check out my health club.',
#  "That's a good idea. Let's go over the weekend.",
#  "Great. I'll call you Saturday morning.",
#  "Alright. I'll talk to you later.",
#  'The weather is terrible.',
#  "Yeah. It's been raining a lot these days.",
#  'I have been watching a lot of videos at home because of the constant rain.',
#  "Have you heard when it's supposed to get better?",
#  "I saw the weather report, and it's going to rain for the next eight days.",
#  'That sucks so much. What are we going to do?',
#  "I'm getting pretty bored. We should do something despite the rain.",
#  "I'm with you. What do you have in mind?",
#  "I haven't been to the Mall in a long time. Let's go there.",
#  'That sounds good. They have a movie theater there, so if we get bored, we can watch a movie.',
#  "Great. I'll stop by your place now.",
#  "Ok. Don't forget to bring your umbrella. The rain can start up again anytime."]

# %%
for i,_ in enumerate(question):
    try:
        question[i] = bytes(_, "utf-8").decode("unicode_escape")
    except Exception as e:
        
        print(i,_, e)

# %%
question
# Out:
# ['"Hi, my name is Steve. It\'s nice to meet you."',
#  '"I\'m Jack. It\'s a pleasure to meet you, Steve."',
#  '"What do you do for a living Jack?"',
#  '"What is your name?"',
#  '"Jackson."',
#  '"Hey John, how have you been?"',
#  '"What a surprise. I haven\'t seen you in a long time. How have you been?"',
#  '"I\'m doing very well. How about you?"',
#  '"Hi Nancy, what have you been up to?"',
#  '"The same ole same ole."',
#  '"Andy, it\'s been a long time, how are you man?"',
#  '"What a surprise. I haven\'t seen you in a long time. How have you been?"',
#  '"Do you come to this restaurant often?"',
#  '"Hi, how are you doing?"',
#  '"I\'m doing great. How about you?"',
#  '"Not too bad."',
#  '"Do you come to this restaurant often?"',
#  '"I\'ve been here a couple of times, but I don\'t come on a regular basis. What have you been up to?"',
#  '"I\'m pretty busy at work these days, but otherwise, everything is great."',
#  '"Well, have a good evening."',
#  '"It\'s nice to meet you. My name is Jack."',
#  '"I\'m Steve. It\'s a pleasure to meet you."',
#  '"What was your name again?"',
#  '"Steve."',
#  '"So Steve, What do you do for a living?"',
#  '"I work at the public library. How about you?"',
#  '"I\'m a University student."',
#  '"That\'s great. It was nice meeting you."',
#  '"Hey Jack, it\'s good to see you."',
#  '"Wow. How long has it been? It seems like more than a year. I\'m doing pretty well. How about you?"',
#  '"Not too bad."',
#  '"What movie did you come to see?"',
#  '"I came here to see Matrix Revolution. How about you?"',
#  '"Hey there. What have you been up to?"',
#  '"Nothing really."',
#  '"How about your work?"',
#  '"It\'s so boring there. I really wish I had a different job."',
#  '"Is it really that bad?"',
#  '"Yeah. Most of the time, I have nothing to do. But whenever I have something to do, it\'s boring work because it is the same old thing."',
#  '"Why don\'t you find a different job then?"',
#  '"Hi Steve, what\'s your plan for tonight?"',
#  '"I don\'t have any plans. Are you doing anything special?"',
#  '"Well, if you\'re bored, let\'s plan on meeting up tonight."',
#  '"That sounds like a good idea. Should we invite Bob?"',
#  '"He\'s a little boring."',
#  '"What do you mean?"',
#  '"Well, he doesn\'t drink, play video games, pool, or really anything. The only thing he talks about is history."',
#  '"You do have a point. We\'ll leave him out tonight."',
#  '"Alright. Let\'s meet in front of the university bookstore."',
#  '"What are you doing now?"',
#  '"I\'m watching TV."',
#  '"What are you watching?"',
#  '"I\'m watching Friends. What are you doing?"',
#  '"I\'m doing my homework, but I really need to take a break."',
#  '"You want to do something?"',
#  '"Yes. But I shouldn\'t. I got to finish my assignment now."',
#  '"Alright. Call me later then."',
#  '"Where are you going now?"',
#  '"I\'m going to the bank."',
#  '"Aren\'t you supposed to be at work?"',
#  '"I\'m working now. I\'m making a deposit for our company."',
#  '"Where do you work?"',
#  '"I work for a restaurant as a controller."',
#  '"Wow. That\'s great."',
#  '"Hi Steve. What are you doing here?"',
#  '"I\'m meeting a friend here for dinner. How about you?"',
#  '"I\'m on my way home but I needed to stop by the book store to buy a text book."',
#  '"Didn\'t you finish school yet?"',
#  '"I have one more year, and then I\'m done."',
#  '"What are you majoring in?"',
#  '"I\'m majoring in Sociology"',
#  '"How do you like your major?"',
#  '"I really find the subject very interesting. I\'m enjoying all my classes."',
#  '"That\'s great."',
#  '"I\'d better go now. I don\'t want to miss the bus."',
#  '"Alright, I\'ll talk to you later."',
#  '"Bob is in the hospital, did you get a chance to visit him?"',
#  '"I\'m going to see Bob tomorrow."',
#  '"I thought you had to meet John tomorrow?"',
#  '"I\'m going home now, do you want to head out together?"',
#  '"No Thanks. I\'m going to go home in about an hour."',
#  '"Didn\'t you need to buy a present for your brother\'s birthday?"',
#  '"I\'m going to go to the bus stop right after class, so I won\'t have time to meet you."',
#  '"Why do you look so stressed?"',
#  '"I\'m going to be dead if I don\'t finish this project by tomorrow."',
#  '"I thought you had 2 weeks to finish this project."',
#  '"Since we are done with school, when are you going back home?"',
#  '"I\'m going to go home next week."',
#  '"Me too. Do you want to meet at the train station on Sunday?"',
#  '"Do you have any plans tonight?"',
#  '"I have class until 5 O\'clock, but I\'m free after that."',
#  '"Do you want to grab dinner?"',
#  '"I don\'t have any dinner plans so that sounds great."',
#  '"What time should we meet?"',
#  '"Let\'s go to Everland next week"',
#  '"I can\'t. I\'m way too busy."',
#  '"What are you doing next week?"',
#  '"On Monday, I\'m going to meet my professor. Tuesday, I have a job interview. Wednesday, I\'m going to the dentist. And on Thursday, I have to go visit my parents."',
#  '"Why are you so busy?"',
#  '"What are you doing over the weekend?"',
#  '"I\'m going to exercise, meet some friends, and then watch tv."',
#  '"Who are you going to meet?"',
#  '"My friend from middle school is visiting, so we are going to have dinner on Saturday."',
#  '"How long is he going to stay?"',
#  '"He is only here for a day."',
#  '"Where are you going to eat dinner?"',
#  '"Why didn\'t you come to my party last night?"',
#  '"I\'m sorry I couldn\'t make it. I had to go visit my grandmother at the hospital."',
#  '"Oh, I\'m sorry to hear that. Is she doing ok?"',
#  '"Did you get a chance to go to that new restaurant down the street?"',
#  '"Yeah. I ordered the special, but the server screwed up my order."',
#  '"That sucks. So what ended up happening?"',
#  '"What did you do last weekend?"',
#  '"I went on a date with Sammy."',
#  '"Really? How was it?"',
#  '"Didn\'t you finish finals week?"',
#  '"Don\'t remind me. I think I failed most of the exams."',
#  '"Why did you do so terrible?"',
#  '"What is the average temperature in Seoul during June?"',
#  '"It is usually about 26 degrees Celsius during June."',
#  '"What is that in Fahrenheit?"',
#  '"What is the weather like in Korea?"',
#  '"Well, the weather in Korea is unique with four distinct seasons. In the winter, the temperature is about zero degrees Celsius. But, because it doesn\'t rain much in the winter, there isn\'t much snow and the air is very dry. In spring, the days warm up significantly but the night gets a little chilly. The summer has two characteristics. It is very hot and humid most of the time, and for about 3 weeks or so, we have a rainy season called monsoon. It gets very rainy and windy during that time period. But we all look forward to autumn. It is a beautiful time of year and the temperature is very pleasant. If you plan on visiting Korea, I highly recommend visiting during autumn."',
#  '',
#  '"Which season do you like the most?"',
#  '"Hey John, it\'s beautiful out today, isn\'t it?"',
#  '"Yeah. I wish it would be like this everyday."',
#  '"Did you see the weather forecast?"',
#  '"Do you know what the weather is going to be like tomorrow?"',
#  '"It\'s supposed to be the same as today. I don\'t think the weather will change much for the next week or so."',
#  '"That\'s great."',
#  '"Why are you so happy? Do you have anything planned?"',
#  '"I can\'t believe it is raining so much."',
#  '"It\'s not that bad. Last year we had floods in 4 different areas of the city."',
#  '"Really? Does it always rain so much during this time of year?"',
#  '"Hi Mary."',
#  '"Oh, hi."',
#  '"How are you doing?"',
#  '"I\'m doing alright. How about you?"',
#  '"Not too bad. The weather is great isn\'t it?"',
#  '"Yes. It\'s absolutely beautiful today."',
#  '"I wish it was like this more frequently."',
#  '"Me too."',
#  '"So where are you going now?"',
#  '"I\'m going to meet a friend of mine at the department store."',
#  '"Going to do a little shopping?"',
#  '"Yeah, I have to buy some presents for my parents."',
#  '"What\'s the occasion?"',
#  '"It\'s their anniversary."',
#  '"That\'s great. Well, you better get going. You don\'t want to be late."',
#  '"I\'ll see you next time."',
#  '"Hi. My name is Josh. It\'s a pleasure to meet you."',
#  '"Hi Josh. I\'m glad to be here."',
#  '"Did you have any problems finding this place."',
#  '"I didn\'t have any problems. I found directions on the internet so it was pretty easy to find. However, the traffic was not that great."',
#  '"Traffic is never good around here."',
#  '"I agree. It would be great if there was a train or a subway line that went through here."',
#  '"That would be so great. I would definitely take the train if they had it."',
#  '"Trains are great because you can read a book or get a little rest instead of having to fight the traffic."',
#  '"Hey John, I\'m going to see The Matrix with Peter and Brad. Do you wanna come?"',
#  '"When are you guys going?"',
#  '"We\'re going to see the eight O\'clock showing."',
#  '"That would be great. Where are you guys meeting?"',
#  '"We\'re meeting at the theater at seven thirty."',
#  '"Hey Jill."',
#  '"What\'s up Mike?"',
#  '"I was wondering if you have any plans for tomorrow night."',
#  '"Umm... I don\'t think I have anything special for tomorrow. Why?"',
#  '"Do you want to see The Titanic with me?"',
#  '"I wanted to see that. Yeah. Let\'s go."',
#  '"What time is good for you?"',
#  '"How about seven thirty."',
#  '"What type of movies do you like?"',
#  '"I like comedies. How about you?"',
#  '"I like action."',
#  '"What type of movies do you like?"',
#  '"I like all sorts of movies, primarily drama and science fiction."',
#  '"That\'s an interesting combination. How about western movies?"',
#  '"Western and horror are the two types of movies I don\'t care for."',
#  '"Why don\'t you like horror? They\'re entertaining."',
#  '"Some are entertaining, but I find most of them stupid and childish. For example, I don\'t understand why a person always goes into the house alone when something is suspicious."',
#  '"Hey, you wanna see a movie tomorrow?"',
#  '"Sounds like a good plan. What do you want to see?"',
#  '"How about Legally Blonde."',
#  '"Ah, my girlfriend wanted to see that movie. I have to take her later so I don\'t want to watch it ahead of time. How about The Cube?"',
#  '"Isn\'t that a scary movie?"',
#  '"How scary can it be? Come on, it\'ll be fun."',
#  '"Ok. I\'ll give it a try."',
#  '"That\'s the spirit. I\'ll see you tomorrow after class."',
#  '"Did you like the movie?"',
#  '"It was better than I thought."',
#  '"The movie didn\'t have many cheesy or stupid scenes."',
#  '"Yeah. I\'m glad that they didn\'t have any love scenes. Sometimes a love scene destroys a good movie."',
#  '"I agree. They didn\'t need that scene."',
#  '"I don\'t see the harm in that scene. They didn\'t do anything or show anything. What\'s the big deal?"',
#  '"That\'s true."',
#  '"But besides those one or two scenes, the movie was great."',
#  '"I liked everything about it. I really liked the samurai that was beating up Cruise in the beginning of the movie. The guy second in command. He was cool too."',
#  '"Every movie has a guy like him. They try to make him awesome even though they don\'t say much."',
#  '"It was clear in the movie that he loved the place and the samurais. Clearly everyone knows that he isn\'t a traitor. I would have done the same thing in his position."',
#  '"I think so too."',
#  '"Well, all the samurais were looking for a death in battle. Cruise wasn\'t."',
#  '"True."',
#  '"What are we going to order?"',
#  '"Me too."',
#  '"Hey Joanne. What are you up to?"',
#  '"I\'m just watching some television."',
#  '"I\'m so bored. I don\'t know what I\'m going to do today and it is only ten in the morning."',
#  '"Me too. Do you think we are boring people?"',
#  '"I don\'t think we are boring. It\'s just that we don\'t have any hobbies."',
#  '"That\'s right. What do you think we should do as a hobby?"',
#  '"That all depends on what you like to do. For example, I like to doodle on the notepad, so I\'m thinking about doing some real drawings."',
#  '"I like to play the piano for fun."',
#  '"Yeah. That can be a good hobby."',
#  '"Hobbies are great. I\'m going to make a list of all the things I like to do."',
#  '"What do you do besides work and watching TV?"',
#  '"When I have some time, I like to exercise."',
#  '"Do you go jogging or do you go to a health club?"',
#  '"I joined Samsung Health Club a couple of months ago."',
#  '"How do you exercise?"',
#  '"I usually spend 30 minutes on the bicycle for the cardio, and then I lift weights for about 45 minutes."',
#  '"How often do you go?"',
#  '"Hey Jimmy. Let\'s go workout later today."',
#  '"Sure. What time do you want to go?"',
#  '30."',
#  '"That sounds good. Today we work on Legs and forearm."',
#  '"Hey. I just played basketball earlier, so my legs are a little sore. Let\'s work out on arms and stomach today."',
#  '"I\'m on a weekly schedule. You\'re messing everything up."',
#  '"C\'mon. We\'re only switching two days. You can do legs on Friday."',
#  '"Damn Scott. You got big."',
#  '"Yeah, I\'ve been working out a lot."',
#  '"How long have you been lifting weights?"',
#  '"For a year and a half."',
#  '"Yeah. Last time I saw you, it was like 2 years ago."',
#  '"Has it been that long?"',
#  '"How often do you go to the gym?"',
#  '"I usually go every other day for about 3 hours."',
#  '"That\'s a lot."',
#  '"Yeah, I used to work out for an hour a day 4 times a week, and I saw no results. This is what you have to do to get noticeable results."',
#  '"I don\'t think I have the discipline for that."',
#  '"How are you doing?"',
#  '"I\'m doing great."',
#  '"What movies have you seen lately?"',
#  '"I saw Forrest Gump the other day."',
#  '"What type of movie is that?"',
#  '"The movie type is drama."',
#  '"I can\'t believe you are watching movies. The weather is great. You should be outside."',
#  '"I hate the hot weather. I\'d rather stay indoors with the air conditioner."',
#  '"What else do you like to do besides watching movies?"',
#  '"I like to play computer games, read books, go shopping, and play pool."',
#  '"Out of those what is your favorite?"',
#  '"My favorite is to play computer games."',
#  '"What is your favorite computer game?"',
#  '"My favorite is Diablo. It used to be Star Craft, but it is getting a little old."',
#  '"If you like to play so much, when do you ever exercise?"',
#  '"Although I hate to exercise, I go jogging at least twice a week."',
#  '"That\'s pretty good. By the way, what are you doing next Saturday?"',
#  '"I am going to go to the bookstore."',
#  '"I am having a party Saturday night at my house. If you have time, you should come."',
#  '"That sounds like fun."',
#  '"Great. I\'ll see you on Saturday."',
#  '"Hello?"',
#  '"Hi Steve. This is Mike. What are you doing?"',
#  '"Oh, hi. I was just watching TV."',
#  '"There\'s nothing to watch right now."',
#  '"I know. I was watching a re-run. I have nothing to do and I was bored."',
#  '"Me too. Let\'s get together and do something."',
#  '"I\'d like to, but I have to meet my parents in an hour for dinner. How about tomorrow?"',
#  '"Yeah. Let\'s plan something tomorrow."',
#  '"Did you hear the weather forecast for tomorrow?"',
#  '"I think it is going to be the same as today. Clear and sunny."',
#  '"That\'s great. We can do something outdoors then."',
#  '"Are there any special events going on tomorrow?"',
#  '"Yeah. I think there\'s a live outdoor concert by the river tomorrow."',
#  '"Oh yeah. I heard about that too. Let\'s go check it out."',
#  '"Do you know what time it starts?"',
#  '"It starts at one PM."',
#  '"Let\'s meet for lunch at eleven thirty and afterwards, we can head over there."',
#  '"Steve. Is that you?"',
#  '"Yeah. What\'s going on?"',
#  '"Not much. What a surprise to see you here."',
#  '"Yeah. It\'s been a couple of months since I saw you."',
#  '"What have you been up to?"',
#  '"I just started working out."',
#  '"Really? Where do you work out at?"',
#  '"I joined the Samsung Health Club last month."',
#  '"What do you mostly do during your workout?"',
#  '"I concentrate mostly on my legs, chest, arms and stomach."',
#  '"I should start exercising more."',
#  '"It\'s hard work while exercising, but it is a great feeling when I get done."',
#  '"I have a running machine at home. I used to use it, but I already got sick of it."',
#  '"Exercising at home is hard. The environment is not suited for exercising."',
#  '"If I want to exercise, I will need to join a gym."',
#  '"I have a couple of guest passes. You want to check out my health club."',
#  '"That\'s a good idea. Let\'s go over the weekend."',
#  '"Great. I\'ll call you Saturday morning."',
#  '"Alright. I\'ll talk to you later."',
#  '"The weather is terrible."',
#  '"Yeah. It\'s been raining a lot these days."',
#  '"I have been watching a lot of videos at home because of the constant rain."',
#  '"Have you heard when it\'s supposed to get better?"',
#  '"I saw the weather report, and it\'s going to rain for the next eight days."',
#  '"That sucks so much. What are we going to do?"',
#  '"I\'m getting pretty bored. We should do something despite the rain."',
#  '"I\'m with you. What do you have in mind?"',
#  '"I haven\'t been to the Mall in a long time. Let\'s go there."',
#  '"That sounds good. They have a movie theater there, so if we get bored, we can watch a movie."',
#  '"Great. I\'ll stop by your place now."',
#  '"Ok. Don\'t forget to bring your umbrella. The rain can start up again anytime."']

# %%
df= pd.DataFrame(list(zip(question, answer)), columns=['question', 'answer'])

# %%
# df.apply(lambda x: repl(x.question,x.answer), axis=1)
df.head()
# Out:
#                                         question  \
# 0   Hi, my name is Steve. It's nice to meet you.
# 1  I'm Jack. It's a pleasure to meet you, Steve.
# 2              What do you do for a living Jack?
# 3                             What is your name?
# 4                                       Jackson.
#
#                                           answer
# 0  I'm Jack. It's a pleasure to meet you, Steve.
# 1              What do you do for a living Jack?
# 2                            I work at the bank.
# 3                                       Jackson.
# 4                           What was that again?

# %% [markdown]
# ### Supreme court dataset Preprocessing

# %%
# Out:
# 'testjhgd'
